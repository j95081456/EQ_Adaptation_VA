# %% [markdown]
# <a href="https://colab.research.google.com/github/j95081456/EQ_Adaptation_VA/blob/main/Mahjong_sim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
from collections import Counter
import matplotlib.pyplot as plt
import time

# Set simulation mode to True to disable visualizations and delays.
SIMULATION = True

# Define Tile class
class Tile:
    def __init__(self, suit, value):
        self.suit = suit
        self.value = value

    def __repr__(self):
        return f"{self.suit}{self.value}"

    def __eq__(self, other):
        return self.suit == other.suit and self.value == other.value

    def __lt__(self, other):
        suit_order = {'B': 0, 'C': 1, 'D': 2, 'W': 3, 'G': 4}  # Bamboo, Characters, Dots, Winds, Dragons
        if self.suit == other.suit:
            return self.value < other.value
        return suit_order[self.suit] < suit_order[other.suit]

    def __hash__(self):
        return hash((self.suit, self.value))

# Define Player class
class Player:
    def __init__(self, name):
        self.name = name
        self.hand = []
        self.melded_sets = []  # Stores Chi, Peng, Gong sets

    def draw_tile(self, tile):
        self.hand.append(tile)
        self.hand.sort()

    def discard_tile(self, index=None):
        if index is not None and index < len(self.hand):
            return self.hand.pop(index)
        else:
            return self.hand.pop()

    def show_hand(self):
        return ' '.join(f"[{i}] {tile}" for i, tile in enumerate(self.hand))

    def can_peng(self, tile):
        return self.hand.count(tile) >= 2

    def can_chi(self, tile):
        if tile.suit not in ['B', 'C', 'D']:
            return False
        values = sorted([t.value for t in self.hand if t.suit == tile.suit])
        return ([tile.value - 1, tile.value + 1] in [values[i:i+2] for i in range(len(values) - 1)]) or \
               ([tile.value - 2, tile.value - 1] in [values[i:i+2] for i in range(len(values) - 1)]) or \
               ([tile.value + 1, tile.value + 2] in [values[i:i+2] for i in range(len(values) - 1)])

    def chi(self, tile):
        possible_sets = [[tile.value - 1, tile.value + 1],
                         [tile.value - 2, tile.value - 1],
                         [tile.value + 1, tile.value + 2]]
        values = sorted([t.value for t in self.hand if t.suit == tile.suit])
        for chi_set in possible_sets:
            if chi_set in [values[i:i+2] for i in range(len(values) - 1)]:
                chi_tiles = [Tile(tile.suit, chi_set[0]), tile, Tile(tile.suit, chi_set[1])]
                self.hand.remove(chi_tiles[0])
                self.hand.remove(chi_tiles[2])
                self.melded_sets.append(chi_tiles)
                print(f"{self.name} 吃 (Chi) {chi_tiles}")
                return True
        return False

    def peng(self, tile):
        self.hand.remove(tile)
        self.hand.remove(tile)
        self.melded_sets.append([tile, tile, tile])
        print(f"{self.name} 碰 (Peng) {tile}")
        return True

    def can_gong(self, tile, from_discard=False):
        # Check for upgrading an existing Peng meld first.
        for meld in self.melded_sets:
            if len(meld) == 3 and all(t == tile for t in meld):
                if self.hand.count(tile) >= 1:
                    return True
        if from_discard:
            # For a discarded tile, three copies in hand suffice.
            return self.hand.count(tile) >= 3
        else:
            # For a drawn tile, require four copies in hand.
            return self.hand.count(tile) >= 4

    def gong(self, tile):
        for meld in self.melded_sets:
            if len(meld) == 3 and all(t == tile for t in meld):
                if tile in self.hand:
                    self.hand.remove(tile)
                    meld.append(tile)
                    print(f"{self.name} 槓 (Gong) by upgrading Peng: {meld}")
                    return True
        if self.hand.count(tile) >= 4:
            for _ in range(4):
                self.hand.remove(tile)
            self.melded_sets.append([tile, tile, tile, tile])
            print(f"{self.name} 槓 (Gong) declared with {tile}")
            return True
        return False

    def check_hu(self):
        total_tiles = len(self.hand) + sum(3 if len(meld) == 4 else len(meld) for meld in self.melded_sets)
        if total_tiles != 14:
            return False
        tile_counts = Counter((tile.suit, tile.value) for tile in self.hand)
        pairs = [tile for tile, count in tile_counts.items() if count >= 2]
        for pair in pairs:
            temp_counts = tile_counts.copy()
            temp_counts[pair] -= 2  # Remove the pair
            if self._can_form_sets(temp_counts):
                return True
        return False

    def _can_form_sets(self, tile_counts):
        if sum(tile_counts.values()) == 0:
            return True
        for tile, count in tile_counts.items():
            if count >= 3:
                temp_counts = tile_counts.copy()
                temp_counts[tile] -= 3
                if self._can_form_sets(temp_counts):
                    return True
            suit, value = tile
            if suit in ['B', 'C', 'D']:
                if all((suit, value + i) in tile_counts and tile_counts[(suit, value + i)] > 0 for i in range(3)):
                    temp_counts = tile_counts.copy()
                    for i in range(3):
                        temp_counts[(suit, value + i)] -= 1
                    if self._can_form_sets(temp_counts):
                        return True
        return False

# Visualization functions (skipped during simulation)
def visualize_hand(player):
    if SIMULATION:
        return
    suits = {'B': 'Bamboo', 'C': 'Characters', 'D': 'Dots', 'W': 'Winds', 'G': 'Dragons'}
    suit_colors = {'B': 'green', 'C': 'red', 'D': 'blue', 'W': 'purple', 'G': 'gold'}
    fig, ax = plt.subplots(figsize=(8, 1.5))
    for idx, tile in enumerate(player.hand):
        ax.text(idx, 0.5, f'{tile.suit}{tile.value}', fontsize=10, ha='center', va='center',
                bbox=dict(facecolor=suit_colors[tile.suit], alpha=0.3))
    ax.set_xlim(-1, len(player.hand))
    ax.set_ylim(0, 1)
    ax.axis('off')
    plt.title(f"{player.name}'s Hand")
    plt.show()

def visualize_melds(player):
    if SIMULATION:
        return
    if not player.melded_sets:
        print(f"{player.name} has no melded sets.")
        return
    suit_colors = {'B': 'green', 'C': 'red', 'D': 'blue', 'W': 'purple', 'G': 'gold'}
    x_offset = 0
    fig, ax = plt.subplots(figsize=(len(player.melded_sets) * 2, 2))
    ax.axis('off')
    for meld in player.melded_sets:
        for idx, tile in enumerate(meld):
            ax.text(x_offset + idx, 0.5, f'{tile.suit}{tile.value}', fontsize=12, ha='center', va='center',
                    bbox=dict(facecolor=suit_colors[tile.suit], alpha=0.3))
        x_offset += len(meld) + 1
    plt.title(f"{player.name}'s Melded Sets (Chi, Peng, Gong)")
    plt.xlim(-1, x_offset)
    plt.ylim(0, 1)
    plt.show()

def ai_discard_strategy_1(player):
    # Smarter AI discard logic: Prefer discarding isolated tiles
    tile_counts = Counter((tile.suit, tile.value) for tile in player.hand)

    # Prioritize discarding unique, non-set-forming tiles
    for tile in player.hand:
        if tile_counts[(tile.suit, tile.value)] == 1:
            return tile

    # If no unique tile, discard the last tile
    return player.hand[-1]

def ai_discard_strategy_2(player):
    tile_scores = {}
    for tile in player.hand:
        score = 0
        count = player.hand.count(tile)

        # Duplicate bonus: more duplicates make the tile more valuable.
        # For each extra copy, reduce the score.
        score -= (count - 1) * 3

        if tile.suit in ['B', 'C', 'D']:
            # For suited tiles, check potential chow formations.
            chow_bonus = 0
            # Possible chow patterns including the tile:
            # 1. (tile, tile+1, tile+2)
            # 2. (tile-1, tile, tile+1)
            # 3. (tile-2, tile-1, tile)
            patterns = [
                (tile.value, tile.value + 1, tile.value + 2),
                (tile.value - 1, tile.value, tile.value + 1),
                (tile.value - 2, tile.value - 1, tile.value)
            ]
            for pattern in patterns:
                bonus = 0
                # The current tile is already in hand; check for the other two.
                for val in pattern:
                    if val == tile.value:
                        continue
                    if 1 <= val <= 9 and Tile(tile.suit, val) in player.hand:
                        bonus += 2  # Each neighboring tile contributes a bonus.
                chow_bonus = max(chow_bonus, bonus)
            score -= chow_bonus

            # If the tile is unique and has no immediate neighbors, add a heavy penalty.
            if count == 1:
                neighbors = [Tile(tile.suit, tile.value - 1), Tile(tile.suit, tile.value + 1)]
                if not any(neighbor in player.hand for neighbor in neighbors):
                    score += 5

        else:
            # For honor tiles (winds/dragons) no chow potential exists.
            if count == 1:
                score += 5

        tile_scores[tile] = score

    # The tile with the highest score (least potential) is chosen for discard.
    discard_tile = max(player.hand, key=lambda t: tile_scores[t])
    return discard_tile

def ai_discard_strategy_3(player):
    """
    Improved discard strategy:
    - For each tile, compute a 'potential' score that rewards duplicates,
      rewards the existence of immediate neighbors (which indicate chow potential),
      and rewards complete or nearly complete sequences.
    - The tile with the highest (i.e. worst) score (lowest potential) is chosen for discard.
    """
    potentials = {}
    for tile in player.hand:
        # Start with a base potential.
        potential = 0
        count = player.hand.count(tile)

        # Duplicates are very valuable.
        if count > 1:
            potential -= (count - 1) * 4  # bonus for each extra copy
        else:
            potential += 10  # isolated tile penalty

        if tile.suit in ['B', 'C', 'D']:
            # Check immediate neighbors (chow potential)
            neighbor_bonus = 0
            for offset in [-2, -1, 1, 2]:
                neighbor_val = tile.value + offset
                if 1 <= neighbor_val <= 9:
                    neighbor_tile = Tile(tile.suit, neighbor_val)
                    if neighbor_tile in player.hand:
                        neighbor_bonus += 3
            potential -= neighbor_bonus

            # Extra bonus if the tile is part of a nearly complete sequence.
            # For example, if tile, tile+1 exist (or tile-1, tile) then waiting for tile+2 (or tile-2) is possible.
            if Tile(tile.suit, tile.value - 1) in player.hand:
                potential -= 5
            if Tile(tile.suit, tile.value + 1) in player.hand:
                potential -= 5
        else:
            # Honor tiles: only duplicates count.
            if count == 1:
                potential += 5
            else:
                potential -= (count - 1) * 3

        potentials[tile] = potential

    # For debugging, you might print out each tile's potential:
    # for t, score in potentials.items():
    #     print(f"{t}: {score}")

    # Choose the tile with the highest potential value (i.e. the worst candidate to keep).
    discard_tile = max(player.hand, key=lambda t: potentials[t])
    return discard_tile


# Improved AI discard strategy
def ai_discard_strategy(player):
    tile_scores = {}
    for tile in player.hand:
        score = 0
        count = player.hand.count(tile)
        if count == 1:
            score += 3
        else:
            score -= count
        if tile.suit in ['B', 'C', 'D']:
            adjacent_bonus = 0
            if Tile(tile.suit, tile.value - 1) in player.hand:
                adjacent_bonus += 2
            if Tile(tile.suit, tile.value + 1) in player.hand:
                adjacent_bonus += 2
            if Tile(tile.suit, tile.value - 2) in player.hand:
                adjacent_bonus += 1
            if Tile(tile.suit, tile.value + 2) in player.hand:
                adjacent_bonus += 1
            score -= adjacent_bonus
        tile_scores[tile] = score
    discard_tile = max(player.hand, key=lambda t: tile_scores[t])
    return discard_tile

# Define Game class
class Game:
    def __init__(self, first_player):
        self.tiles = self.initialize_tiles()
        random.shuffle(self.tiles)
        self.players = [Player("NPC 1"), Player("NPC 2"), Player("NPC 3"), Player("NPC 4")]
        self.last_player = None  # Last player who discarded a tile
        self.current_player = first_player  # Index of current player
        self.distribute_tiles()

    def initialize_tiles(self):
        suits = ['B', 'C', 'D']
        winds = ['E', 'S', 'W', 'N']
        dragons = ['R', 'G', 'H']
        tiles = [Tile(suit, value) for suit in suits for value in range(1, 10) for _ in range(4)]
        tiles += [Tile('W', wind) for wind in winds for _ in range(4)]
        tiles += [Tile('G', dragon) for dragon in dragons for _ in range(4)]
        return tiles

    def distribute_tiles(self):
        for _ in range(13):
            for player in self.players:
                player.draw_tile(self.tiles.pop())

    def play_game(self):
        round_number = 1
        last_discarded_tile = None
        while True:
            tile_claimed = False
            player = self.players[self.current_player]

            # Check if any player can win by claiming the discarded tile.
            if last_discarded_tile:
                for p in self.players:
                    if p != self.last_player:
                        total_tiles = len(p.hand) + sum(3 if len(meld) == 4 else len(meld) for meld in p.melded_sets)
                        if total_tiles + 1 == 14:
                            p.hand.append(last_discarded_tile)
                            if p.check_hu():
                                print(f"🎉 {p.name} wins with a Hu hand by claiming the discarded tile {last_discarded_tile}! 🎉")
                                return p.name
                            else:
                                p.hand.pop()

            # Check for Gong, Peng, or Chi with the discarded tile.
            if last_discarded_tile:
                for p in self.players:
                    if p != self.last_player and p.can_gong(last_discarded_tile, from_discard=True):
                        tile_claimed = p.gong(last_discarded_tile)
                        if tile_claimed:
                            if self.tiles:
                                supplemental_tile = self.tiles.pop()
                                p.draw_tile(supplemental_tile)
                                print(f"{p.name} draws supplemental tile: {supplemental_tile}")
                            self.current_player = self.players.index(p)
                            player = p
                            last_discarded_tile = None
                            break

                if not tile_claimed:
                    for p in self.players:
                        if p != self.last_player and p.can_peng(last_discarded_tile):
                            tile_claimed = p.peng(last_discarded_tile)
                            if tile_claimed:
                                self.current_player = self.players.index(p)
                                player = p
                                last_discarded_tile = None
                                break

                if not tile_claimed and player.can_chi(last_discarded_tile):
                    tile_claimed = player.chi(last_discarded_tile)
                    if tile_claimed:
                        last_discarded_tile = None

            if tile_claimed and player.check_hu():
                print(f"🎉 {player.name} wins with a Hu hand! 🎉")
                return player.name

            print(f"\nRound {round_number} - {player.name}'s turn")
            # (Visualizations skipped in simulation mode.)
            visualize_hand(player)
            visualize_melds(player)

            # Draw a tile if available.
            if not tile_claimed and self.tiles:
                drawn_tile = self.tiles.pop()
                player.draw_tile(drawn_tile)
                print(f"{player.name} drew: {drawn_tile}")
                for tile in set(player.hand):
                    if player.can_gong(tile, from_discard=False):
                        if player.gong(tile):
                            if self.tiles:
                                supplemental_tile = self.tiles.pop()
                                player.draw_tile(supplemental_tile)
                                print(f"{player.name} draws supplemental tile: {supplemental_tile}")
                            break
                if player.check_hu():
                    print(f"🎉 {player.name} wins with a Hu hand! 🎉")
                    return player.name
            elif not self.tiles:
                print("No more tiles left! It's a draw.")
                return "Draw"

            # Discard a tile automatically.
            if player.name == "NPC 1":
                discard = ai_discard_strategy_3(player)
            else:
                discard = ai_discard_strategy(player)

           # discard = ai_discard_strategy(player)
            player.hand.remove(discard)
            last_discarded_tile = discard
            print(f"{player.name} discarded: {discard}")

            self.last_player = player
            self.current_player = (self.current_player + 1) % 4
            if self.current_player == 0:
                round_number += 1

           # if not SIMULATION:
           #     time.sleep(3)
           # else:
           #     time.sleep(0.1)

# Main simulation: Run 10 games and record wins.
if __name__ == "__main__":
    win_counts = {"NPC 1": 0, "NPC 2": 0, "NPC 3": 0, "NPC 4": 0, "Draw": 0}
    num_games = 1000
    for i in range(num_games):
        print(f"\n=== Starting Game {i+1} ===")
        game = Game(first_player = i%4)
        result = game.play_game()
        win_counts[result] += 1
        print(f"Game {i+1} result: {result}")
    print("\n=== Simulation Results ===")
    for player, wins in win_counts.items():
        print(f"{player}: {wins} win(s)")
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#
# Round 5 - NPC 3's turn
# NPC 3 discarded: C4
#
# Round 5 - NPC 4's turn
# NPC 4 drew: WN
# NPC 4 discarded: WN
# NPC 2 碰 (Peng) WN
#
# Round 6 - NPC 2's turn
# NPC 2 discarded: D9
#
# Round 6 - NPC 3's turn
# NPC 3 drew: C6
# NPC 3 discarded: C6
#
# Round 6 - NPC 4's turn
# NPC 4 drew: WW
# NPC 4 discarded: WW
#
# Round 7 - NPC 1's turn
# NPC 1 drew: D3
# NPC 1 discarded: C2
#
# Round 7 - NPC 2's turn
# NPC 2 drew: B1
# NPC 2 discarded: B1
#
# Round 7 - NPC 3's turn
# NPC 3 drew: C1
# NPC 3 discarded: C1
#
# Round 7 - NPC 4's turn
# NPC 4 drew: D7
# NPC 4 discarded: D7
# NPC 3 碰 (Peng) D7
#
# Round 8 - NPC 3's turn
# NPC 3 discarded: D1
#
# Round 8 - NPC 4's turn
# NPC 4 drew: C9
# NPC 4 discarded: C9
#
# Round 9 - NPC 1's turn
# NPC 1 drew: WW
# NPC 1 discarded: WW
#
# Round 9 - NPC 2's turn
# NPC 2 drew: GG
# NPC 2 discarded: WW
#
# Round 9 - NPC 3's turn
# NPC 3 drew: D5
# NPC 3 discarded: GG
#
# Round 9 - NPC 4's turn
# NPC 4 drew: C3
# NPC 4 discarded: C3
#
# Round 10 - NPC 1's turn
# NPC 1 drew: C5
# NPC 1 discarded: B4
#
# Round 10 - NPC 2's turn
# NPC 2 drew: C7
# NPC 2 discarded: C7
#
# Round 10 - NPC 3's turn
# NPC 3 drew: D4
# NPC 3 discarded: B1
# NPC 4 吃 (Chi) [B2, B1, B3]
#
# Round 10 - NPC 4's turn
# NPC 4 discarded: GG
#
# Round 11 - NPC 1's turn
# NPC 1 drew: GH
# NPC 1 discarded: GH
# NPC 2 碰 (Peng) GH
#
# Round 11 - NPC 2's turn
# NPC 2 discarded: GG
#
# Round 11 - NPC 3's turn
# NPC 3 drew: D1
# NPC 3 discarded: B3
# 🎉 NPC 4 wins with a Hu hand by claiming the discarded tile B3! 🎉
# Game 972 result: NPC 4
#
# === Starting Game 973 ===
#
# Round 1 - NPC 1's turn
# NPC 1 drew: WE
# NPC 1 discarded: WE
#
# Round 1 - NPC 2's turn
# NPC 2 drew: B8
# NPC 2 discarded: C1
#
# Round 1 - NPC 3's turn
# NPC 3 drew: D7
# NPC 3 discarded: D2
#
# Round 1 - NPC 4's turn
# NPC 4 drew: D4
# NPC 4 discarded: B4
#
# Round 2 - NPC 1's turn
# NPC 1 drew: B8
# NPC 1 discarded: WN
#
# Round 2 - NPC 2's turn
# NPC 2 drew: B4
# NPC 2 discarded: D8
#
# Round 2 - NPC 3's turn
# NPC 3 drew: B6
# NPC 3 discarded: GH
#
# Round 2 - NPC 4's turn
# NPC 4 drew: D3
# NPC 4 discarded: WN
#
# Round 3 - NPC 1's turn
# NPC 1 drew: D5
# NPC 1 discarded: GR
# NPC 3 碰 (Peng) GR
#
# Round 3 - NPC 3's turn
# NPC 3 discarded: B9
#
# Round 3 - NPC 4's turn
# NPC 4 drew: D6
# NPC 4 discarded: WW
# NPC 1 碰 (Peng) WW
#
# Round 4 - NPC 1's turn
# NPC 1 discarded: B4
# NPC 2 吃 (Chi) [B2, B4, B3]
#
# Round 4 - NPC 2's turn
# NPC 2 discarded: WN
#
# Round 4 - NPC 3's turn
# NPC 3 drew: B5
# NPC 3 discarded: B8
#
# Round 4 - NPC 4's turn
# NPC 4 drew: D4
# NPC 4 discarded: GR
#
# Round 5 - NPC 1's turn
# NPC 1 drew: GG
# NPC 1 discarded: GG
#
# Round 5 - NPC 2's turn
# NPC 2 drew: D3
# NPC 2 discarded: D3
#
# Round 5 - NPC 3's turn
# NPC 3 drew: WS
# NPC 3 discarded: WS
#
# Round 5 - NPC 4's turn
# NPC 4 drew: C3
# NPC 4 discarded: C7
# NPC 3 碰 (Peng) C7
#
# Round 6 - NPC 3's turn
# NPC 3 discarded: B5
#
# Round 6 - NPC 4's turn
# NPC 4 drew: B6
# NPC 4 discarded: B6
# 🎉 NPC 3 wins with a Hu hand by claiming the discarded tile B6! 🎉
# Game 973 result: NPC 3
#
# === Starting Game 974 ===
#
# Round 1 - NPC 2's turn
# NPC 2 drew: B9
# NPC 2 discarded: B9
#
# Round 1 - NPC 3's turn
# NPC 3 drew: D6
# NPC 3 discarded: C8
#
# Round 1 - NPC 4's turn
# NPC 4 drew: D3
# NPC 4 discarded: WN
#
# Round 2 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
#
# Round 2 - NPC 2's turn
# NPC 2 drew: B7
# NPC 2 discarded: B7
# NPC 3 吃 (Chi) [B5, B7, B6]
#
# Round 2 - NPC 3's turn
# NPC 3 discarded: B7
#
# Round 2 - NPC 4's turn
# NPC 4 drew: WW
# NPC 4 discarded: WS
#
# Round 3 - NPC 1's turn
# NPC 1 drew: B1
# NPC 1 discarded: GH
#
# Round 3 - NPC 2's turn
# NPC 2 drew: WS
# NPC 2 discarded: WS
#
# Round 3 - NPC 3's turn
# NPC 3 drew: B1
# NPC 3 discarded: B1
# NPC 1 碰 (Peng) B1
#
# Round 3 - NPC 1's turn
# NPC 1 discarded: GR
#
# Round 3 - NPC 2's turn
# NPC 2 drew: D1
# NPC 2 discarded: D1
#
# Round 3 - NPC 3's turn
# NPC 3 drew: B8
# NPC 3 discarded: B8
#
# Round 3 - NPC 4's turn
# NPC 4 drew: C5
# NPC 4 discarded: C8
#
# Round 4 - NPC 1's turn
# NPC 1 drew: B2
# NPC 1 discarded: B8
#
# Round 4 - NPC 2's turn
# NPC 2 drew: B6
# NPC 2 discarded: B6
#
# Round 4 - NPC 3's turn
# NPC 3 drew: B5
# NPC 3 discarded: B5
#
# Round 4 - NPC 4's turn
# NPC 4 drew: B8
# NPC 4 discarded: B8
#
# Round 5 - NPC 1's turn
# NPC 1 drew: B6
# NPC 1 discarded: C4
#
# Round 5 - NPC 2's turn
# NPC 2 drew: C5
# NPC 2 discarded: C9
#
# Round 5 - NPC 3's turn
# NPC 3 drew: D2
# NPC 3 discarded: WE
# NPC 2 碰 (Peng) WE
#
# Round 5 - NPC 2's turn
# NPC 2 discarded: B3
#
# Round 5 - NPC 3's turn
# NPC 3 drew: D4
# NPC 3 discarded: WN
#
# Round 5 - NPC 4's turn
# NPC 4 drew: B7
# NPC 4 discarded: B7
# NPC 1 吃 (Chi) [B5, B7, B6]
#
# Round 6 - NPC 1's turn
# NPC 1 discarded: C9
#
# Round 6 - NPC 2's turn
# NPC 2 drew: D9
# NPC 2 discarded: C5
# NPC 3 吃 (Chi) [C3, C5, C4]
#
# Round 6 - NPC 3's turn
# NPC 3 discarded: GG
# NPC 1 碰 (Peng) GG
#
# Round 6 - NPC 1's turn
# NPC 1 discarded: D5
#
# Round 6 - NPC 2's turn
# NPC 2 drew: C5
# NPC 2 discarded: C5
#
# Round 6 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: D9
# NPC 2 碰 (Peng) D9
#
# Round 6 - NPC 2's turn
# NPC 2 discarded: C6
#
# Round 6 - NPC 3's turn
# NPC 3 drew: C3
# NPC 3 discarded: C3
# NPC 4 吃 (Chi) [C1, C3, C2]
#
# Round 6 - NPC 4's turn
# NPC 4 discarded: D7
#
# Round 7 - NPC 1's turn
# NPC 1 drew: WN
# NPC 1 discarded: WN
#
# Round 7 - NPC 2's turn
# NPC 2 drew: D3
# NPC 2 discarded: D3
# NPC 4 碰 (Peng) D3
#
# Round 7 - NPC 4's turn
# NPC 4 discarded: D2
# NPC 3 碰 (Peng) D2
#
# Round 8 - NPC 3's turn
# NPC 3 discarded: GR
#
# Round 8 - NPC 4's turn
# NPC 4 drew: GH
# NPC 4 discarded: D5
#
# Round 9 - NPC 1's turn
# NPC 1 drew: B3
# NPC 1 discarded: B4
# 🎉 NPC 2 wins with a Hu hand by claiming the discarded tile B4! 🎉
# Game 974 result: NPC 2
#
# === Starting Game 975 ===
#
# Round 1 - NPC 3's turn
# NPC 3 drew: C8
# NPC 3 discarded: B3
# NPC 4 吃 (Chi) [B1, B3, B2]
#
# Round 1 - NPC 4's turn
# NPC 4 discarded: C5
# NPC 1 吃 (Chi) [C4, C5, C6]
#
# Round 2 - NPC 1's turn
# NPC 1 discarded: B5
# NPC 2 碰 (Peng) B5
#
# Round 2 - NPC 2's turn
# NPC 2 discarded: C4
# NPC 3 吃 (Chi) [C3, C4, C5]
#
# Round 2 - NPC 3's turn
# NPC 3 discarded: B6
#
# Round 2 - NPC 4's turn
# NPC 4 drew: B1
# NPC 4 discarded: B1
#
# Round 3 - NPC 1's turn
# NPC 1 drew: D9
# NPC 1 discarded: C2
#
# Round 3 - NPC 2's turn
# NPC 2 drew: C9
# NPC 2 槓 (Gong) declared with C9
# NPC 2 draws supplemental tile: B1
# NPC 2 discarded: B1
#
# Round 3 - NPC 3's turn
# NPC 3 drew: D2
# NPC 3 discarded: B9
#
# Round 3 - NPC 4's turn
# NPC 4 drew: C2
# NPC 4 discarded: WS
#
# Round 4 - NPC 1's turn
# NPC 1 drew: B9
# NPC 1 discarded: B9
#
# Round 4 - NPC 2's turn
# NPC 2 drew: D8
# NPC 2 discarded: WN
#
# Round 4 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: C8
# NPC 2 碰 (Peng) C8
#
# Round 4 - NPC 2's turn
# NPC 2 discarded: C7
#
# Round 4 - NPC 3's turn
# NPC 3 drew: C4
# NPC 3 discarded: C4
#
# Round 4 - NPC 4's turn
# NPC 4 drew: C6
# NPC 4 discarded: C6
#
# Round 5 - NPC 1's turn
# NPC 1 drew: D8
# NPC 1 discarded: C8
#
# Round 5 - NPC 2's turn
# NPC 2 drew: B4
# NPC 2 discarded: B4
#
# Round 5 - NPC 3's turn
# NPC 3 drew: D2
# NPC 3 discarded: WE
# NPC 1 碰 (Peng) WE
#
# Round 5 - NPC 1's turn
# NPC 1 discarded: D1
#
# Round 5 - NPC 2's turn
# NPC 2 drew: D1
# NPC 2 discarded: D1
# NPC 3 吃 (Chi) [D2, D1, D3]
#
# Round 5 - NPC 3's turn
# NPC 3 discarded: WN
#
# Round 5 - NPC 4's turn
# NPC 4 drew: C6
# NPC 4 discarded: C6
#
# Round 6 - NPC 1's turn
# NPC 1 drew: D2
# NPC 1 discarded: D2
#
# Round 6 - NPC 2's turn
# NPC 2 drew: B4
# NPC 2 discarded: B4
#
# Round 6 - NPC 3's turn
# NPC 3 drew: B8
# NPC 3 discarded: B8
#
# Round 6 - NPC 4's turn
# NPC 4 drew: GR
# NPC 4 discarded: B6
#
# Round 7 - NPC 1's turn
# NPC 1 drew: C4
# NPC 1 discarded: C4
#
# Round 7 - NPC 2's turn
# NPC 2 drew: B9
# NPC 2 discarded: B9
#
# Round 7 - NPC 3's turn
# NPC 3 drew: D4
# NPC 3 discarded: GH
#
# Round 7 - NPC 4's turn
# NPC 4 drew: B3
# NPC 4 discarded: B3
# NPC 1 吃 (Chi) [B1, B3, B2]
#
# Round 8 - NPC 1's turn
# NPC 1 discarded: D4
#
# Round 8 - NPC 2's turn
# NPC 2 drew: GH
# NPC 2 discarded: WW
#
# Round 8 - NPC 3's turn
# NPC 3 drew: C7
# NPC 3 discarded: C7
#
# Round 8 - NPC 4's turn
# NPC 4 drew: D3
# NPC 4 discarded: B8
#
# Round 9 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
#
# Round 9 - NPC 2's turn
# NPC 2 drew: B7
# NPC 2 discarded: B7
#
# Round 9 - NPC 3's turn
# NPC 3 drew: D6
# NPC 3 discarded: D1
#
# Round 9 - NPC 4's turn
# NPC 4 drew: WS
# NPC 4 discarded: WS
#
# Round 10 - NPC 1's turn
# NPC 1 drew: C3
# NPC 1 discarded: C3
#
# Round 10 - NPC 2's turn
# NPC 2 drew: D8
# NPC 2 discarded: GH
#
# Round 10 - NPC 3's turn
# NPC 3 drew: WN
# NPC 3 discarded: WN
#
# Round 10 - NPC 4's turn
# NPC 4 drew: GR
# NPC 4 discarded: D1
#
# Round 11 - NPC 1's turn
# NPC 1 drew: C6
# NPC 1 discarded: C6
#
# Round 11 - NPC 2's turn
# NPC 2 drew: D5
# NPC 2 discarded: D5
# 🎉 NPC 1 wins with a Hu hand by claiming the discarded tile D5! 🎉
# Game 975 result: NPC 1
#
# === Starting Game 976 ===
#
# Round 1 - NPC 4's turn
# NPC 4 drew: D1
# NPC 4 discarded: B1
#
# Round 2 - NPC 1's turn
# NPC 1 drew: D8
# NPC 1 discarded: WW
#
# Round 2 - NPC 2's turn
# NPC 2 drew: B3
# NPC 2 discarded: WE
#
# Round 2 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: D1
#
# Round 2 - NPC 4's turn
# NPC 4 drew: GR
# NPC 4 discarded: C2
# NPC 1 碰 (Peng) C2
#
# Round 3 - NPC 1's turn
# NPC 1 discarded: C8
# NPC 2 吃 (Chi) [C7, C8, C9]
#
# Round 3 - NPC 2's turn
# NPC 2 discarded: WN
#
# Round 3 - NPC 3's turn
# NPC 3 drew: B7
# NPC 3 discarded: D4
# NPC 4 吃 (Chi) [D5, D4, D6]
#
# Round 3 - NPC 4's turn
# NPC 4 discarded: D8
#
# Round 4 - NPC 1's turn
# NPC 1 drew: GH
# NPC 1 discarded: GH
#
# Round 4 - NPC 2's turn
# NPC 2 drew: C5
# NPC 2 discarded: C5
#
# Round 4 - NPC 3's turn
# NPC 3 drew: C3
# NPC 3 discarded: WN
#
# Round 4 - NPC 4's turn
# NPC 4 drew: WW
# NPC 4 discarded: WW
#
# Round 5 - NPC 1's turn
# NPC 1 drew: B8
# NPC 1 discarded: B8
#
# Round 5 - NPC 2's turn
# NPC 2 drew: B2
# NPC 2 discarded: WW
#
# Round 5 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: GG
#
# Round 5 - NPC 4's turn
# NPC 4 drew: C9
# NPC 4 discarded: GH
#
# Round 6 - NPC 1's turn
# NPC 1 drew: C5
# NPC 1 discarded: C5
#
# Round 6 - NPC 2's turn
# NPC 2 drew: B8
# NPC 2 discarded: B8
#
# Round 6 - NPC 3's turn
# NPC 3 drew: D7
# NPC 3 discarded: GH
#
# Round 6 - NPC 4's turn
# NPC 4 drew: B9
# NPC 4 discarded: GR
#
# Round 7 - NPC 1's turn
# NPC 1 drew: B8
# NPC 1 discarded: B8
#
# Round 7 - NPC 2's turn
# NPC 2 drew: B2
# NPC 2 discarded: GG
#
# Round 7 - NPC 3's turn
# NPC 3 drew: D3
# NPC 3 discarded: D3
# NPC 1 碰 (Peng) D3
#
# Round 7 - NPC 1's turn
# NPC 1 discarded: D1
#
# Round 7 - NPC 2's turn
# NPC 2 drew: C4
# NPC 2 discarded: C4
#
# Round 7 - NPC 3's turn
# NPC 3 drew: C6
# NPC 3 discarded: C6
# NPC 4 碰 (Peng) C6
#
# Round 7 - NPC 4's turn
# NPC 4 discarded: B9
#
# Round 8 - NPC 1's turn
# NPC 1 drew: D6
# NPC 1 discarded: B1
# NPC 2 吃 (Chi) [B2, B1, B3]
#
# Round 8 - NPC 2's turn
# NPC 2 discarded: B2
#
# Round 8 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: GR
#
# Round 8 - NPC 4's turn
# NPC 4 drew: B7
# NPC 4 discarded: C5
#
# Round 9 - NPC 1's turn
# NPC 1 drew: D8
# NPC 1 discarded: B3
# NPC 3 碰 (Peng) B3
#
# Round 9 - NPC 3's turn
# NPC 3 discarded: B5
# NPC 4 吃 (Chi) [B6, B5, B7]
#
# Round 9 - NPC 4's turn
# NPC 4 discarded: B7
# NPC 3 碰 (Peng) B7
#
# Round 10 - NPC 3's turn
# NPC 3 discarded: C1
#
# Round 10 - NPC 4's turn
# NPC 4 drew: WE
# NPC 4 discarded: WE
#
# Round 11 - NPC 1's turn
# NPC 1 drew: B1
# NPC 1 discarded: B1
#
# Round 11 - NPC 2's turn
# NPC 2 drew: C8
# NPC 2 discarded: C8
#
# Round 11 - NPC 3's turn
# NPC 3 drew: C7
# NPC 3 discarded: C7
#
# Round 11 - NPC 4's turn
# NPC 4 drew: D7
# NPC 4 discarded: D7
# 🎉 NPC 3 wins with a Hu hand by claiming the discarded tile D7! 🎉
# Game 976 result: NPC 3
#
# === Starting Game 977 ===
#
# Round 1 - NPC 1's turn
# NPC 1 drew: C4
# NPC 1 discarded: WN
#
# Round 1 - NPC 2's turn
# NPC 2 drew: B7
# NPC 2 discarded: D9
#
# Round 1 - NPC 3's turn
# NPC 3 drew: WN
# NPC 3 discarded: B7
#
# Round 1 - NPC 4's turn
# NPC 4 drew: B2
# NPC 4 discarded: B2
# NPC 1 吃 (Chi) [B1, B2, B3]
#
# Round 2 - NPC 1's turn
# NPC 1 discarded: GG
#
# Round 2 - NPC 2's turn
# NPC 2 drew: D9
# NPC 2 discarded: D9
#
# Round 2 - NPC 3's turn
# NPC 3 drew: C9
# NPC 3 discarded: C9
#
# Round 2 - NPC 4's turn
# NPC 4 drew: D3
# NPC 4 discarded: C7
# NPC 2 碰 (Peng) C7
#
# Round 3 - NPC 2's turn
# NPC 2 discarded: C6
# NPC 3 吃 (Chi) [C4, C6, C5]
#
# Round 3 - NPC 3's turn
# NPC 3 discarded: D2
# NPC 4 吃 (Chi) [D1, D2, D3]
#
# Round 3 - NPC 4's turn
# NPC 4 discarded: D3
#
# Round 4 - NPC 1's turn
# NPC 1 drew: C6
# NPC 1 discarded: B1
#
# Round 4 - NPC 2's turn
# NPC 2 drew: B3
# NPC 2 discarded: WS
#
# Round 4 - NPC 3's turn
# NPC 3 drew: C1
# NPC 3 discarded: D8
# NPC 4 碰 (Peng) D8
#
# Round 4 - NPC 4's turn
# NPC 4 discarded: B7
# NPC 1 吃 (Chi) [B6, B7, B8]
#
# Round 5 - NPC 1's turn
# NPC 1 discarded: B9
#
# Round 5 - NPC 2's turn
# NPC 2 drew: WW
# NPC 2 discarded: GG
#
# Round 5 - NPC 3's turn
# NPC 3 drew: C8
# NPC 3 discarded: C8
#
# Round 5 - NPC 4's turn
# NPC 4 drew: D7
# NPC 4 discarded: D7
#
# Round 6 - NPC 1's turn
# NPC 1 drew: C6
# NPC 1 discarded: D9
#
# Round 6 - NPC 2's turn
# NPC 2 drew: B9
# NPC 2 discarded: GR
#
# Round 6 - NPC 3's turn
# NPC 3 drew: B1
# NPC 3 discarded: WE
#
# Round 6 - NPC 4's turn
# NPC 4 drew: D8
# NPC 4 槓 (Gong) by upgrading Peng: [D8, D8, D8, D8]
# NPC 4 draws supplemental tile: C5
# NPC 4 discarded: C2
# NPC 1 吃 (Chi) [C3, C2, C4]
#
# Round 7 - NPC 1's turn
# NPC 1 discarded: D4
# NPC 2 吃 (Chi) [D5, D4, D6]
#
# Round 7 - NPC 2's turn
# NPC 2 discarded: B7
#
# Round 7 - NPC 3's turn
# NPC 3 drew: WS
# NPC 3 discarded: WS
#
# Round 7 - NPC 4's turn
# NPC 4 drew: D4
# NPC 4 discarded: D4
#
# Round 8 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
#
# Round 8 - NPC 2's turn
# NPC 2 drew: C2
# NPC 2 discarded: C2
# NPC 3 吃 (Chi) [C1, C2, C3]
#
# Round 8 - NPC 3's turn
# NPC 3 discarded: C1
#
# Round 8 - NPC 4's turn
# NPC 4 drew: D1
# NPC 4 discarded: D1
#
# Round 9 - NPC 1's turn
# NPC 1 drew: WE
# NPC 1 discarded: WE
#
# Round 9 - NPC 2's turn
# NPC 2 drew: D4
# NPC 2 discarded: D4
#
# Round 9 - NPC 3's turn
# NPC 3 drew: C7
# NPC 3 discarded: C7
#
# Round 9 - NPC 4's turn
# NPC 4 drew: D9
# NPC 4 discarded: D9
#
# Round 10 - NPC 1's turn
# NPC 1 drew: B3
# NPC 1 discarded: B3
# NPC 2 吃 (Chi) [B4, B3, B5]
#
# Round 10 - NPC 2's turn
# NPC 2 discarded: B3
#
# Round 10 - NPC 3's turn
# NPC 3 drew: C9
# NPC 3 discarded: C9
#
# Round 10 - NPC 4's turn
# NPC 4 drew: C5
# NPC 4 discarded: C3
#
# Round 11 - NPC 1's turn
# NPC 1 drew: C8
# NPC 1 discarded: D6
#
# Round 11 - NPC 2's turn
# NPC 2 drew: D7
# NPC 2 discarded: D7
#
# Round 11 - NPC 3's turn
# NPC 3 drew: C9
# NPC 3 discarded: C9
#
# Round 11 - NPC 4's turn
# NPC 4 drew: GR
# NPC 4 discarded: GR
#
# Round 12 - NPC 1's turn
# NPC 1 drew: C8
# NPC 1 discarded: C5
# NPC 4 碰 (Peng) C5
#
# Round 12 - NPC 4's turn
# NPC 4 discarded: C4
#
# Round 13 - NPC 1's turn
# NPC 1 drew: B4
# NPC 1 discarded: B4
#
# Round 13 - NPC 2's turn
# NPC 2 drew: D2
# NPC 2 discarded: D2
#
# Round 13 - NPC 3's turn
# NPC 3 drew: WN
# NPC 3 discarded: GH
#
# Round 13 - NPC 4's turn
# NPC 4 drew: C2
# NPC 4 discarded: C2
#
# Round 14 - NPC 1's turn
# NPC 1 drew: C3
# NPC 1 discarded: C3
#
# Round 14 - NPC 2's turn
# NPC 2 drew: B5
# NPC 2 discarded: B5
# 🎉 NPC 4 wins with a Hu hand by claiming the discarded tile B5! 🎉
# Game 977 result: NPC 4
#
# === Starting Game 978 ===
#
# Round 1 - NPC 2's turn
# NPC 2 drew: D8
# NPC 2 discarded: B7
# NPC 3 吃 (Chi) [B6, B7, B8]
#
# Round 1 - NPC 3's turn
# NPC 3 discarded: D2
#
# Round 1 - NPC 4's turn
# NPC 4 drew: D2
# NPC 4 discarded: C1
#
# Round 2 - NPC 1's turn
# NPC 1 drew: GR
# NPC 1 discarded: WE
#
# Round 2 - NPC 2's turn
# NPC 2 drew: D7
# NPC 2 discarded: C8
#
# Round 2 - NPC 3's turn
# NPC 3 drew: C1
# NPC 3 discarded: D8
# NPC 2 碰 (Peng) D8
#
# Round 2 - NPC 2's turn
# NPC 2 discarded: D1
#
# Round 2 - NPC 3's turn
# NPC 3 drew: C8
# NPC 3 discarded: C8
#
# Round 2 - NPC 4's turn
# NPC 4 drew: B7
# NPC 4 discarded: C7
#
# Round 3 - NPC 1's turn
# NPC 1 drew: C9
# NPC 1 discarded: WN
#
# Round 3 - NPC 2's turn
# NPC 2 drew: D7
# NPC 2 discarded: WN
#
# Round 3 - NPC 3's turn
# NPC 3 drew: C6
# NPC 3 discarded: WE
#
# Round 3 - NPC 4's turn
# NPC 4 drew: GG
# NPC 4 discarded: D2
#
# Round 4 - NPC 1's turn
# NPC 1 drew: D5
# NPC 1 discarded: WS
# NPC 4 碰 (Peng) WS
#
# Round 4 - NPC 4's turn
# NPC 4 discarded: D6
# NPC 1 吃 (Chi) [D5, D6, D7]
#
# Round 5 - NPC 1's turn
# NPC 1 discarded: WW
#
# Round 5 - NPC 2's turn
# NPC 2 drew: D5
# NPC 2 discarded: GG
# NPC 4 碰 (Peng) GG
#
# Round 5 - NPC 4's turn
# NPC 4 discarded: D9
#
# Round 6 - NPC 1's turn
# NPC 1 drew: B2
# NPC 1 discarded: GH
#
# Round 6 - NPC 2's turn
# NPC 2 drew: C7
# NPC 2 discarded: GR
#
# Round 6 - NPC 3's turn
# NPC 3 drew: B5
# NPC 3 discarded: B5
# NPC 4 吃 (Chi) [B6, B5, B7]
#
# Round 6 - NPC 4's turn
# NPC 4 discarded: WW
#
# Round 7 - NPC 1's turn
# NPC 1 drew: D4
# NPC 1 discarded: GR
#
# Round 7 - NPC 2's turn
# NPC 2 drew: C4
# NPC 2 discarded: B1
#
# Round 7 - NPC 3's turn
# NPC 3 drew: B9
# NPC 3 槓 (Gong) declared with B9
# NPC 3 draws supplemental tile: C3
# NPC 3 discarded: WS
#
# Round 7 - NPC 4's turn
# NPC 4 drew: D2
# NPC 4 槓 (Gong) by upgrading Peng: [GG, GG, GG, GG]
# NPC 4 draws supplemental tile: GH
# NPC 4 discarded: D2
# NPC 1 吃 (Chi) [D3, D2, D4]
#
# Round 8 - NPC 1's turn
# NPC 1 discarded: B8
#
# Round 8 - NPC 2's turn
# NPC 2 drew: WN
# NPC 2 discarded: B3
#
# Round 8 - NPC 3's turn
# NPC 3 drew: B1
# NPC 3 discarded: B1
#
# Round 8 - NPC 4's turn
# NPC 4 drew: C5
# NPC 4 discarded: C5
#
# Round 9 - NPC 1's turn
# NPC 1 drew: C6
# NPC 1 discarded: C2
#
# Round 9 - NPC 2's turn
# NPC 2 drew: B2
# NPC 2 discarded: B2
# NPC 1 碰 (Peng) B2
#
# Round 9 - NPC 1's turn
# NPC 1 discarded: D2
#
# Round 9 - NPC 2's turn
# NPC 2 drew: B7
# NPC 2 discarded: B7
#
# Round 9 - NPC 3's turn
# NPC 3 drew: C4
# NPC 3 discarded: GH
# NPC 4 碰 (Peng) GH
#
# Round 9 - NPC 4's turn
# NPC 4 discarded: B7
#
# Round 10 - NPC 1's turn
# NPC 1 drew: B1
# NPC 1 discarded: B1
#
# Round 10 - NPC 2's turn
# NPC 2 drew: D6
# NPC 2 discarded: WN
#
# Round 10 - NPC 3's turn
# NPC 3 drew: B4
# NPC 3 discarded: B4
#
# Round 10 - NPC 4's turn
# NPC 4 drew: B3
# NPC 4 discarded: B3
#
# Round 11 - NPC 1's turn
# NPC 1 drew: B4
# NPC 1 discarded: B4
#
# Round 11 - NPC 2's turn
# NPC 2 drew: D9
# NPC 2 discarded: C2
# NPC 3 吃 (Chi) [C1, C2, C3]
#
# Round 11 - NPC 3's turn
# NPC 3 discarded: GR
#
# Round 11 - NPC 4's turn
# NPC 4 drew: B4
# NPC 4 discarded: B4
#
# Round 12 - NPC 1's turn
# NPC 1 drew: C9
# NPC 1 discarded: D9
#
# Round 12 - NPC 2's turn
# NPC 2 drew: WW
# NPC 2 discarded: WW
#
# Round 12 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: D9
#
# Round 12 - NPC 4's turn
# NPC 4 drew: D4
# NPC 4 discarded: B8
#
# Round 13 - NPC 1's turn
# NPC 1 drew: D3
# NPC 1 discarded: D3
#
# Round 13 - NPC 2's turn
# NPC 2 drew: C9
# NPC 2 discarded: C9
# NPC 1 碰 (Peng) C9
#
# Round 13 - NPC 1's turn
# NPC 1 discarded: C6
# 🎉 NPC 3 wins with a Hu hand by claiming the discarded tile C6! 🎉
# Game 978 result: NPC 3
#
# === Starting Game 979 ===
#
# Round 1 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: B1
#
# Round 1 - NPC 4's turn
# NPC 4 drew: D1
# NPC 4 discarded: B9
#
# Round 2 - NPC 1's turn
# NPC 1 drew: C5
# NPC 1 discarded: WE
# NPC 3 碰 (Peng) WE
#
# Round 2 - NPC 3's turn
# NPC 3 discarded: C3
# NPC 4 碰 (Peng) C3
#
# Round 2 - NPC 4's turn
# NPC 4 discarded: B1
#
# Round 3 - NPC 1's turn
# NPC 1 drew: WN
# NPC 1 discarded: WN
#
# Round 3 - NPC 2's turn
# NPC 2 drew: WS
# NPC 2 discarded: C2
# NPC 4 碰 (Peng) C2
#
# Round 3 - NPC 4's turn
# NPC 4 discarded: B2
#
# Round 4 - NPC 1's turn
# NPC 1 drew: GG
# NPC 1 discarded: GG
#
# Round 4 - NPC 2's turn
# NPC 2 drew: WS
# NPC 2 discarded: C7
#
# Round 4 - NPC 3's turn
# NPC 3 drew: B9
# NPC 3 槓 (Gong) by upgrading Peng: [WE, WE, WE, WE]
# NPC 3 draws supplemental tile: WW
# NPC 3 discarded: D1
#
# Round 4 - NPC 4's turn
# NPC 4 drew: WN
# NPC 4 discarded: WN
#
# Round 5 - NPC 1's turn
# NPC 1 drew: C8
# NPC 1 discarded: D2
#
# Round 5 - NPC 2's turn
# NPC 2 drew: C4
# NPC 2 discarded: C4
#
# Round 5 - NPC 3's turn
# NPC 3 drew: C9
# NPC 3 discarded: C9
# NPC 4 吃 (Chi) [C7, C9, C8]
#
# Round 5 - NPC 4's turn
# NPC 4 discarded: C6
#
# Round 6 - NPC 1's turn
# NPC 1 drew: C6
# NPC 1 discarded: C5
#
# Round 6 - NPC 2's turn
# NPC 2 drew: C9
# NPC 2 discarded: C9
#
# Round 6 - NPC 3's turn
# NPC 3 drew: B3
# NPC 3 discarded: WN
#
# Round 6 - NPC 4's turn
# NPC 4 drew: WW
# NPC 4 discarded: WW
#
# Round 7 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
# NPC 2 碰 (Peng) WS
#
# Round 7 - NPC 2's turn
# NPC 2 discarded: D2
#
# Round 7 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: WW
#
# Round 7 - NPC 4's turn
# NPC 4 drew: B3
# NPC 4 discarded: B3
#
# Round 8 - NPC 1's turn
# NPC 1 drew: D3
# NPC 1 discarded: D3
# 🎉 NPC 4 wins with a Hu hand by claiming the discarded tile D3! 🎉
# Game 979 result: NPC 4
#
# === Starting Game 980 ===
#
# Round 1 - NPC 4's turn
# NPC 4 drew: GG
# NPC 4 discarded: D2
# NPC 2 碰 (Peng) D2
#
# Round 2 - NPC 2's turn
# NPC 2 discarded: C2
#
# Round 2 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: B1
#
# Round 2 - NPC 4's turn
# NPC 4 drew: D8
# NPC 4 discarded: D5
#
# Round 3 - NPC 1's turn
# NPC 1 drew: C9
# NPC 1 discarded: D1
# NPC 2 碰 (Peng) D1
#
# Round 3 - NPC 2's turn
# NPC 2 discarded: D5
# NPC 3 吃 (Chi) [D6, D5, D7]
#
# Round 3 - NPC 3's turn
# NPC 3 discarded: D6
#
# Round 3 - NPC 4's turn
# NPC 4 drew: GG
# NPC 4 discarded: D8
#
# Round 4 - NPC 1's turn
# NPC 1 drew: GH
# NPC 1 discarded: GH
#
# Round 4 - NPC 2's turn
# NPC 2 drew: D4
# NPC 2 discarded: D4
#
# Round 4 - NPC 3's turn
# NPC 3 drew: WW
# NPC 3 discarded: WW
#
# Round 4 - NPC 4's turn
# NPC 4 drew: C6
# NPC 4 discarded: WE
#
# Round 5 - NPC 1's turn
# NPC 1 drew: C4
# NPC 1 discarded: C4
#
# Round 5 - NPC 2's turn
# NPC 2 drew: B1
# NPC 2 discarded: WE
#
# Round 5 - NPC 3's turn
# NPC 3 drew: D1
# NPC 3 discarded: GG
# NPC 4 碰 (Peng) GG
#
# Round 5 - NPC 4's turn
# NPC 4 discarded: WS
# NPC 3 碰 (Peng) WS
#
# Round 6 - NPC 3's turn
# NPC 3 discarded: GH
#
# Round 6 - NPC 4's turn
# NPC 4 drew: B1
# NPC 4 discarded: B1
#
# Round 7 - NPC 1's turn
# NPC 1 drew: B1
# NPC 1 discarded: B1
#
# Round 7 - NPC 2's turn
# NPC 2 drew: D6
# NPC 2 discarded: D6
#
# Round 7 - NPC 3's turn
# NPC 3 drew: WE
# NPC 3 discarded: WE
#
# Round 7 - NPC 4's turn
# NPC 4 drew: D9
# NPC 4 discarded: D9
# NPC 3 碰 (Peng) D9
#
# Round 8 - NPC 3's turn
# NPC 3 discarded: D1
#
# Round 8 - NPC 4's turn
# NPC 4 drew: GR
# NPC 4 discarded: GR
#
# Round 9 - NPC 1's turn
# NPC 1 drew: D3
# NPC 1 discarded: C9
#
# Round 9 - NPC 2's turn
# NPC 2 drew: D2
# NPC 2 槓 (Gong) by upgrading Peng: [D2, D2, D2, D2]
# NPC 2 draws supplemental tile: C8
# NPC 2 discarded: GR
#
# Round 9 - NPC 3's turn
# NPC 3 drew: B8
# NPC 3 discarded: B7
#
# Round 9 - NPC 4's turn
# NPC 4 drew: B2
# NPC 4 discarded: B2
# NPC 1 吃 (Chi) [B3, B2, B4]
#
# Round 10 - NPC 1's turn
# NPC 1 discarded: D3
# 🎉 NPC 3 wins with a Hu hand by claiming the discarded tile D3! 🎉
# Game 980 result: NPC 3
#
# === Starting Game 981 ===
#
# Round 1 - NPC 1's turn
# NPC 1 drew: WW
# NPC 1 discarded: WW
#
# Round 1 - NPC 2's turn
# NPC 2 drew: C8
# NPC 2 discarded: C8
#
# Round 1 - NPC 3's turn
# NPC 3 drew: B1
# NPC 3 discarded: B9
#
# Round 1 - NPC 4's turn
# NPC 4 drew: B4
# NPC 4 discarded: WN
#
# Round 2 - NPC 1's turn
# NPC 1 drew: D4
# NPC 1 discarded: B1
# NPC 3 碰 (Peng) B1
#
# Round 2 - NPC 3's turn
# NPC 3 discarded: C1
#
# Round 2 - NPC 4's turn
# NPC 4 drew: C6
# NPC 4 discarded: B6
#
# Round 3 - NPC 1's turn
# NPC 1 drew: GH
# NPC 1 discarded: GH
# NPC 3 碰 (Peng) GH
#
# Round 3 - NPC 3's turn
# NPC 3 discarded: C6
# NPC 4 碰 (Peng) C6
#
# Round 3 - NPC 4's turn
# NPC 4 discarded: C4
#
# Round 4 - NPC 1's turn
# NPC 1 drew: D6
# NPC 1 discarded: B7
# NPC 2 吃 (Chi) [B6, B7, B8]
#
# Round 4 - NPC 2's turn
# NPC 2 discarded: B9
#
# Round 4 - NPC 3's turn
# NPC 3 drew: B3
# NPC 3 discarded: B3
# 🎉 NPC 4 wins with a Hu hand by claiming the discarded tile B3! 🎉
# Game 981 result: NPC 4
#
# === Starting Game 982 ===
#
# Round 1 - NPC 2's turn
# NPC 2 drew: C3
# NPC 2 discarded: D1
#
# Round 1 - NPC 3's turn
# NPC 3 drew: C4
# NPC 3 discarded: D3
#
# Round 1 - NPC 4's turn
# NPC 4 drew: GH
# NPC 4 discarded: C4
# NPC 3 碰 (Peng) C4
#
# Round 2 - NPC 3's turn
# NPC 3 discarded: WN
# NPC 4 碰 (Peng) WN
#
# Round 2 - NPC 4's turn
# NPC 4 discarded: C9
#
# Round 3 - NPC 1's turn
# NPC 1 drew: C8
# NPC 1 discarded: WE
#
# Round 3 - NPC 2's turn
# NPC 2 drew: D4
# NPC 2 discarded: WE
#
# Round 3 - NPC 3's turn
# NPC 3 drew: D4
# NPC 3 discarded: D4
#
# Round 3 - NPC 4's turn
# NPC 4 drew: B6
# NPC 4 discarded: D1
#
# Round 4 - NPC 1's turn
# NPC 1 drew: B9
# NPC 1 discarded: WS
#
# Round 4 - NPC 2's turn
# NPC 2 drew: WS
# NPC 2 discarded: WS
#
# Round 4 - NPC 3's turn
# NPC 3 drew: B5
# NPC 3 discarded: B5
#
# Round 4 - NPC 4's turn
# NPC 4 drew: B3
# NPC 4 discarded: B3
#
# Round 5 - NPC 1's turn
# NPC 1 drew: D5
# NPC 1 discarded: GG
#
# Round 5 - NPC 2's turn
# NPC 2 drew: C7
# NPC 2 discarded: WW
#
# Round 5 - NPC 3's turn
# NPC 3 drew: C2
# NPC 3 discarded: C2
#
# Round 5 - NPC 4's turn
# NPC 4 drew: B5
# NPC 4 discarded: WW
#
# Round 6 - NPC 1's turn
# NPC 1 drew: B3
# NPC 1 discarded: C5
#
# Round 6 - NPC 2's turn
# NPC 2 drew: B8
# NPC 2 discarded: B8
#
# Round 6 - NPC 3's turn
# NPC 3 drew: WN
# NPC 3 discarded: WN
#
# Round 6 - NPC 4's turn
# NPC 4 drew: D5
# NPC 4 discarded: D5
# NPC 2 碰 (Peng) D5
#
# Round 7 - NPC 2's turn
# NPC 2 discarded: B4
#
# Round 7 - NPC 3's turn
# NPC 3 drew: B3
# NPC 3 discarded: GG
#
# Round 7 - NPC 4's turn
# NPC 4 drew: C2
# NPC 4 discarded: C2
#
# Round 8 - NPC 1's turn
# NPC 1 drew: B5
# NPC 1 discarded: C8
#
# Round 8 - NPC 2's turn
# NPC 2 drew: B8
# NPC 2 discarded: B8
#
# Round 8 - NPC 3's turn
# NPC 3 drew: C3
# NPC 3 discarded: GH
# NPC 4 碰 (Peng) GH
#
# Round 8 - NPC 4's turn
# NPC 4 discarded: GG
#
# Round 9 - NPC 1's turn
# NPC 1 drew: D2
# NPC 1 discarded: B7
#
# Round 9 - NPC 2's turn
# NPC 2 drew: B5
# NPC 2 discarded: B5
#
# Round 9 - NPC 3's turn
# NPC 3 drew: C7
# NPC 3 discarded: C3
#
# Round 9 - NPC 4's turn
# NPC 4 drew: B1
# NPC 4 discarded: B1
#
# Round 10 - NPC 1's turn
# NPC 1 drew: B9
# NPC 1 discarded: B3
# NPC 2 吃 (Chi) [B1, B3, B2]
#
# Round 10 - NPC 2's turn
# NPC 2 discarded: C3
#
# Round 10 - NPC 3's turn
# NPC 3 drew: D7
# NPC 3 discarded: D7
# NPC 1 碰 (Peng) D7
#
# Round 10 - NPC 1's turn
# NPC 1 discarded: D8
# NPC 2 吃 (Chi) [D6, D8, D7]
#
# Round 10 - NPC 2's turn
# NPC 2 discarded: D4
#
# Round 10 - NPC 3's turn
# NPC 3 drew: B2
# NPC 3 discarded: B1
#
# Round 10 - NPC 4's turn
# NPC 4 drew: GR
# NPC 4 discarded: B8
#
# Round 11 - NPC 1's turn
# NPC 1 drew: D6
# NPC 1 discarded: B4
#
# Round 11 - NPC 2's turn
# NPC 2 drew: B2
# NPC 2 discarded: B2
# NPC 3 碰 (Peng) B2
#
# Round 11 - NPC 3's turn
# NPC 3 discarded: B3
#
# Round 11 - NPC 4's turn
# NPC 4 drew: B7
# NPC 4 discarded: D8
#
# Round 12 - NPC 1's turn
# NPC 1 drew: D1
# NPC 1 discarded: B5
#
# Round 12 - NPC 2's turn
# NPC 2 drew: C6
# NPC 2 discarded: C5
# NPC 3 吃 (Chi) [C6, C5, C7]
#
# Round 12 - NPC 3's turn
# NPC 3 discarded: C5
#
# Round 12 - NPC 4's turn
# NPC 4 drew: D2
# NPC 4 discarded: D2
#
# Round 13 - NPC 1's turn
# NPC 1 drew: D2
# NPC 1 discarded: D5
#
# Round 13 - NPC 2's turn
# NPC 2 drew: D6
# NPC 2 discarded: D6
# NPC 1 碰 (Peng) D6
#
# Round 13 - NPC 1's turn
# NPC 1 discarded: D3
#
# Round 13 - NPC 2's turn
# NPC 2 drew: C8
# NPC 2 discarded: C6
#
# Round 13 - NPC 3's turn
# NPC 3 drew: C1
# NPC 3 discarded: C1
#
# Round 13 - NPC 4's turn
# NPC 4 drew: C1
# NPC 4 discarded: C1
#
# Round 14 - NPC 1's turn
# NPC 1 drew: B1
# NPC 1 discarded: B1
#
# Round 14 - NPC 2's turn
# NPC 2 drew: D4
# NPC 2 discarded: D4
#
# Round 14 - NPC 3's turn
# NPC 3 drew: B7
# NPC 3 discarded: B7
# NPC 4 吃 (Chi) [B5, B7, B6]
#
# Round 14 - NPC 4's turn
# NPC 4 discarded: D9
# 🎉 NPC 3 wins with a Hu hand by claiming the discarded tile D9! 🎉
# Game 982 result: NPC 3
#
# === Starting Game 983 ===
#
# Round 1 - NPC 3's turn
# NPC 3 drew: C1
# NPC 3 discarded: B3
# NPC 2 碰 (Peng) B3
#
# Round 1 - NPC 2's turn
# NPC 2 discarded: D1
# NPC 3 吃 (Chi) [D2, D1, D3]
#
# Round 1 - NPC 3's turn
# NPC 3 discarded: D7
# NPC 4 吃 (Chi) [D6, D7, D8]
#
# Round 1 - NPC 4's turn
# NPC 4 discarded: B5
#
# Round 2 - NPC 1's turn
# NPC 1 drew: C9
# NPC 1 discarded: WN
# NPC 2 碰 (Peng) WN
#
# Round 2 - NPC 2's turn
# NPC 2 discarded: D5
#
# Round 2 - NPC 3's turn
# NPC 3 drew: C6
# NPC 3 discarded: B7
#
# Round 2 - NPC 4's turn
# NPC 4 drew: D9
# NPC 4 discarded: C8
#
# Round 3 - NPC 1's turn
# NPC 1 drew: B4
# NPC 1 discarded: GR
#
# Round 3 - NPC 2's turn
# NPC 2 drew: D9
# NPC 2 discarded: D9
#
# Round 3 - NPC 3's turn
# NPC 3 drew: WN
# NPC 3 discarded: WN
#
# Round 3 - NPC 4's turn
# NPC 4 drew: B9
# NPC 4 discarded: B9
# NPC 1 吃 (Chi) [B7, B9, B8]
#
# Round 4 - NPC 1's turn
# NPC 1 discarded: D9
#
# Round 4 - NPC 2's turn
# NPC 2 drew: WS
# NPC 2 discarded: WS
#
# Round 4 - NPC 3's turn
# NPC 3 drew: B3
# NPC 3 discarded: B3
# NPC 4 吃 (Chi) [B1, B3, B2]
#
# Round 4 - NPC 4's turn
# NPC 4 discarded: D3
#
# Round 5 - NPC 1's turn
# NPC 1 drew: B8
# NPC 1 discarded: B8
# NPC 2 吃 (Chi) [B7, B8, B9]
#
# Round 5 - NPC 2's turn
# NPC 2 discarded: C6
#
# Round 5 - NPC 3's turn
# NPC 3 drew: D2
# NPC 3 discarded: D2
#
# Round 5 - NPC 4's turn
# NPC 4 drew: D7
# NPC 4 discarded: WE
#
# Round 6 - NPC 1's turn
# NPC 1 drew: WW
# NPC 1 discarded: WW
#
# Round 6 - NPC 2's turn
# NPC 2 drew: B6
# NPC 2 discarded: B5
#
# Round 6 - NPC 3's turn
# NPC 3 drew: D8
# NPC 3 discarded: D8
#
# Round 6 - NPC 4's turn
# NPC 4 drew: C5
# NPC 4 discarded: C5
#
# Round 7 - NPC 1's turn
# NPC 1 drew: C4
# NPC 1 discarded: C4
#
# Round 7 - NPC 2's turn
# NPC 2 drew: C1
# NPC 2 discarded: C1
# NPC 3 碰 (Peng) C1
#
# Round 7 - NPC 3's turn
# NPC 3 discarded: B8
#
# Round 7 - NPC 4's turn
# NPC 4 drew: D4
# NPC 4 discarded: D4
#
# Round 8 - NPC 1's turn
# NPC 1 drew: D5
# NPC 1 discarded: C5
#
# Round 8 - NPC 2's turn
# NPC 2 drew: B9
# NPC 2 discarded: B9
#
# Round 8 - NPC 3's turn
# NPC 3 drew: C7
# NPC 3 discarded: B9
#
# Round 8 - NPC 4's turn
# NPC 4 drew: D6
# NPC 4 discarded: WS
#
# Round 9 - NPC 1's turn
# NPC 1 drew: C3
# NPC 1 discarded: C3
#
# Round 9 - NPC 2's turn
# NPC 2 drew: B6
# NPC 2 discarded: C8
# NPC 3 吃 (Chi) [C6, C8, C7]
#
# Round 9 - NPC 3's turn
# NPC 3 discarded: C2
#
# Round 9 - NPC 4's turn
# NPC 4 drew: B6
# NPC 4 discarded: B6
# NPC 2 碰 (Peng) B6
#
# Round 10 - NPC 2's turn
# NPC 2 discarded: B6
#
# Round 10 - NPC 3's turn
# NPC 3 drew: D2
# NPC 3 discarded: D2
#
# Round 10 - NPC 4's turn
# NPC 4 drew: B8
# NPC 4 discarded: B8
#
# Round 11 - NPC 1's turn
# NPC 1 drew: WW
# NPC 1 discarded: WW
#
# Round 11 - NPC 2's turn
# NPC 2 drew: D1
# NPC 2 discarded: C9
# NPC 1 碰 (Peng) C9
#
# Round 11 - NPC 1's turn
# NPC 1 discarded: C6
#
# Round 11 - NPC 2's turn
# NPC 2 drew: C2
# NPC 2 discarded: C2
#
# Round 11 - NPC 3's turn
# NPC 3 drew: GR
# NPC 3 discarded: GR
#
# Round 11 - NPC 4's turn
# NPC 4 drew: WS
# NPC 4 discarded: WS
#
# Round 12 - NPC 1's turn
# NPC 1 drew: C7
# NPC 1 discarded: C7
# NPC 3 碰 (Peng) C7
#
# Round 12 - NPC 3's turn
# NPC 3 discarded: C3
#
# Round 12 - NPC 4's turn
# NPC 4 drew: D3
# NPC 4 discarded: D3
#
# Round 13 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
#
# Round 13 - NPC 2's turn
# NPC 2 drew: D8
# NPC 2 discarded: D1
#
# Round 13 - NPC 3's turn
# NPC 3 drew: WE
# NPC 3 discarded: C5
#
# Round 13 - NPC 4's turn
# NPC 4 drew: GH
# NPC 4 discarded: WW
#
# Round 14 - NPC 1's turn
# NPC 1 drew: D3
# NPC 1 discarded: D3
#
# Round 14 - NPC 2's turn
# NPC 2 drew: WE
# NPC 2 discarded: D8
#
# Round 14 - NPC 3's turn
# NPC 3 drew: D1
# NPC 3 discarded: D1
#
# Round 14 - NPC 4's turn
# NPC 4 drew: D5
# NPC 4 discarded: GH
#
# Round 15 - NPC 1's turn
# NPC 1 drew: B5
# NPC 1 discarded: B5
#
# Round 15 - NPC 2's turn
# NPC 2 drew: D4
# NPC 2 discarded: D4
# 🎉 NPC 4 wins with a Hu hand by claiming the discarded tile D4! 🎉
# Game 983 result: NPC 4
#
# === Starting Game 984 ===
#
# Round 1 - NPC 4's turn
# NPC 4 drew: B5
# NPC 4 discarded: B9
#
# Round 2 - NPC 1's turn
# NPC 1 drew: WN
# NPC 1 discarded: WE
#
# Round 2 - NPC 2's turn
# NPC 2 drew: C3
# NPC 2 discarded: B8
#
# Round 2 - NPC 3's turn
# NPC 3 drew: D4
# NPC 3 discarded: WN
#
# Round 2 - NPC 4's turn
# NPC 4 drew: B7
# NPC 4 discarded: C9
#
# Round 3 - NPC 1's turn
# NPC 1 drew: WW
# NPC 1 discarded: WN
#
# Round 3 - NPC 2's turn
# NPC 2 drew: B5
# NPC 2 discarded: B5
# NPC 4 碰 (Peng) B5
#
# Round 3 - NPC 4's turn
# NPC 4 discarded: WE
#
# Round 4 - NPC 1's turn
# NPC 1 drew: D3
# NPC 1 discarded: WS
#
# Round 4 - NPC 2's turn
# NPC 2 drew: D3
# NPC 2 discarded: D3
# NPC 1 碰 (Peng) D3
#
# Round 4 - NPC 1's turn
# NPC 1 discarded: WW
#
# Round 4 - NPC 2's turn
# NPC 2 drew: D9
# NPC 2 discarded: WW
#
# Round 4 - NPC 3's turn
# NPC 3 drew: B7
# NPC 3 discarded: B7
#
# Round 4 - NPC 4's turn
# NPC 4 drew: D9
# NPC 4 discarded: WW
#
# Round 5 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
#
# Round 5 - NPC 2's turn
# NPC 2 drew: GR
# NPC 2 discarded: GG
#
# Round 5 - NPC 3's turn
# NPC 3 drew: WE
# NPC 3 discarded: WE
#
# Round 5 - NPC 4's turn
# NPC 4 drew: C4
# NPC 4 discarded: GH
#
# Round 6 - NPC 1's turn
# NPC 1 drew: WW
# NPC 1 discarded: WW
#
# Round 6 - NPC 2's turn
# NPC 2 drew: GG
# NPC 2 discarded: GG
#
# Round 6 - NPC 3's turn
# NPC 3 drew: WE
# NPC 3 discarded: WE
#
# Round 6 - NPC 4's turn
# NPC 4 drew: D1
# NPC 4 discarded: D1
#
# Round 7 - NPC 1's turn
# NPC 1 drew: B8
# NPC 1 discarded: GH
#
# Round 7 - NPC 2's turn
# NPC 2 drew: B4
# NPC 2 discarded: GR
#
# Round 7 - NPC 3's turn
# NPC 3 drew: B4
# NPC 3 discarded: GG
#
# Round 7 - NPC 4's turn
# NPC 4 drew: C8
# NPC 4 discarded: C8
#
# Round 8 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
#
# Round 8 - NPC 2's turn
# NPC 2 drew: C8
# NPC 2 discarded: B4
# NPC 3 碰 (Peng) B4
#
# Round 8 - NPC 3's turn
# NPC 3 discarded: GR
#
# Round 8 - NPC 4's turn
# NPC 4 drew: B1
# NPC 4 discarded: B1
#
# Round 9 - NPC 1's turn
# NPC 1 drew: C5
# NPC 1 discarded: C2
#
# Round 9 - NPC 2's turn
# NPC 2 drew: D1
# NPC 2 discarded: D1
#
# Round 9 - NPC 3's turn
# NPC 3 drew: C3
# NPC 3 discarded: B1
#
# Round 9 - NPC 4's turn
# NPC 4 drew: C7
# NPC 4 discarded: C7
#
# Round 10 - NPC 1's turn
# NPC 1 drew: C8
# NPC 1 discarded: C5
# NPC 3 碰 (Peng) C5
#
# Round 10 - NPC 3's turn
# NPC 3 discarded: B3
# NPC 1 碰 (Peng) B3
#
# Round 10 - NPC 1's turn
# NPC 1 discarded: B3
# NPC 2 吃 (Chi) [B1, B3, B2]
#
# Round 10 - NPC 2's turn
# NPC 2 discarded: C2
#
# Round 10 - NPC 3's turn
# NPC 3 drew: B8
# NPC 3 discarded: B8
# NPC 4 吃 (Chi) [B6, B8, B7]
#
# Round 10 - NPC 4's turn
# NPC 4 discarded: C1
#
# Round 11 - NPC 1's turn
# NPC 1 drew: WN
# NPC 1 discarded: WN
#
# Round 11 - NPC 2's turn
# NPC 2 drew: B9
# NPC 2 discarded: B9
#
# Round 11 - NPC 3's turn
# NPC 3 drew: C9
# NPC 3 discarded: C3
# 🎉 NPC 2 wins with a Hu hand by claiming the discarded tile C3! 🎉
# Game 984 result: NPC 2
#
# === Starting Game 985 ===
#
# Round 1 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: GR
#
# Round 1 - NPC 2's turn
# NPC 2 drew: C7
# NPC 2 discarded: B1
# NPC 4 碰 (Peng) B1
#
# Round 1 - NPC 4's turn
# NPC 4 discarded: B7
#
# Round 2 - NPC 1's turn
# NPC 1 drew: C7
# NPC 1 discarded: C1
#
# Round 2 - NPC 2's turn
# NPC 2 drew: GH
# NPC 2 discarded: C3
#
# Round 2 - NPC 3's turn
# NPC 3 drew: D3
# NPC 3 discarded: C2
#
# Round 2 - NPC 4's turn
# NPC 4 drew: C2
# NPC 4 discarded: C2
#
# Round 3 - NPC 1's turn
# NPC 1 drew: B4
# NPC 1 discarded: B4
# NPC 2 吃 (Chi) [B5, B4, B6]
#
# Round 3 - NPC 2's turn
# NPC 2 discarded: D8
#
# Round 3 - NPC 3's turn
# NPC 3 drew: D3
# NPC 3 discarded: D9
#
# Round 3 - NPC 4's turn
# NPC 4 drew: GH
# NPC 4 discarded: D1
# NPC 3 碰 (Peng) D1
#
# Round 4 - NPC 3's turn
# NPC 3 discarded: WE
#
# Round 4 - NPC 4's turn
# NPC 4 drew: C9
# NPC 4 discarded: WE
#
# Round 5 - NPC 1's turn
# NPC 1 drew: C2
# NPC 1 discarded: C2
#
# Round 5 - NPC 2's turn
# NPC 2 drew: C5
# NPC 2 discarded: WN
#
# Round 5 - NPC 3's turn
# NPC 3 drew: B3
# NPC 3 discarded: D6
# NPC 1 碰 (Peng) D6
#
# Round 5 - NPC 1's turn
# NPC 1 discarded: D3
# NPC 3 碰 (Peng) D3
#
# Round 5 - NPC 3's turn
# NPC 3 discarded: D5
#
# Round 5 - NPC 4's turn
# NPC 4 drew: WS
# NPC 4 discarded: WN
#
# Round 6 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 槓 (Gong) by upgrading Peng: [D6, D6, D6, D6]
# NPC 1 draws supplemental tile: C1
# NPC 1 discarded: C1
#
# Round 6 - NPC 2's turn
# NPC 2 drew: C4
# NPC 2 discarded: WW
#
# Round 6 - NPC 3's turn
# NPC 3 drew: B4
# NPC 3 discarded: B1
# NPC 4 吃 (Chi) [B2, B1, B3]
#
# Round 6 - NPC 4's turn
# NPC 4 discarded: B4
#
# Round 7 - NPC 1's turn
# NPC 1 drew: D1
# NPC 1 discarded: D1
# NPC 2 吃 (Chi) [D2, D1, D3]
#
# Round 7 - NPC 2's turn
# NPC 2 discarded: D4
#
# Round 7 - NPC 3's turn
# NPC 3 drew: C3
# NPC 3 discarded: C3
#
# Round 7 - NPC 4's turn
# NPC 4 drew: D4
# NPC 4 discarded: D4
#
# Round 8 - NPC 1's turn
# NPC 1 drew: D2
# NPC 1 discarded: D2
#
# Round 8 - NPC 2's turn
# NPC 2 drew: B4
# NPC 2 discarded: B4
# NPC 3 吃 (Chi) [B2, B4, B3]
#
# Round 8 - NPC 3's turn
# NPC 3 discarded: B4
#
# Round 8 - NPC 4's turn
# NPC 4 drew: GG
# NPC 4 discarded: WS
# NPC 1 碰 (Peng) WS
#
# Round 9 - NPC 1's turn
# NPC 1 discarded: WS
#
# Round 9 - NPC 2's turn
# NPC 2 drew: D8
# NPC 2 discarded: D8
#
# Round 9 - NPC 3's turn
# NPC 3 drew: D4
# NPC 3 discarded: D4
#
# Round 9 - NPC 4's turn
# NPC 4 drew: GG
# NPC 4 discarded: WW
#
# Round 10 - NPC 1's turn
# NPC 1 drew: C4
# NPC 1 discarded: C4
# NPC 2 吃 (Chi) [C5, C4, C6]
#
# Round 10 - NPC 2's turn
# NPC 2 discarded: C4
#
# Round 10 - NPC 3's turn
# NPC 3 drew: C5
# NPC 3 discarded: C5
#
# Round 10 - NPC 4's turn
# NPC 4 drew: B9
# NPC 4 discarded: B9
# 🎉 NPC 3 wins with a Hu hand by claiming the discarded tile B9! 🎉
# Game 985 result: NPC 3
#
# === Starting Game 986 ===
#
# Round 1 - NPC 2's turn
# NPC 2 drew: D1
# NPC 2 discarded: D9
#
# Round 1 - NPC 3's turn
# NPC 3 drew: B6
# NPC 3 discarded: D1
# NPC 2 碰 (Peng) D1
#
# Round 1 - NPC 2's turn
# NPC 2 discarded: GR
#
# Round 1 - NPC 3's turn
# NPC 3 drew: D6
# NPC 3 discarded: D9
#
# Round 1 - NPC 4's turn
# NPC 4 drew: GH
# NPC 4 discarded: B4
#
# Round 2 - NPC 1's turn
# NPC 1 drew: B7
# NPC 1 discarded: WW
#
# Round 2 - NPC 2's turn
# NPC 2 drew: D2
# NPC 2 discarded: C2
#
# Round 2 - NPC 3's turn
# NPC 3 drew: D5
# NPC 3 discarded: WW
#
# Round 2 - NPC 4's turn
# NPC 4 drew: C2
# NPC 4 discarded: C7
# NPC 3 碰 (Peng) C7
#
# Round 3 - NPC 3's turn
# NPC 3 discarded: GR
#
# Round 3 - NPC 4's turn
# NPC 4 drew: C8
# NPC 4 discarded: C8
#
# Round 4 - NPC 1's turn
# NPC 1 drew: WE
# NPC 1 discarded: WE
#
# Round 4 - NPC 2's turn
# NPC 2 drew: C4
# NPC 2 discarded: B1
#
# Round 4 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: D9
#
# Round 4 - NPC 4's turn
# NPC 4 drew: C6
# NPC 4 discarded: C6
# NPC 3 碰 (Peng) C6
#
# Round 5 - NPC 3's turn
# NPC 3 discarded: B2
#
# Round 5 - NPC 4's turn
# NPC 4 drew: B1
# NPC 4 discarded: B1
#
# Round 6 - NPC 1's turn
# NPC 1 drew: B3
# NPC 1 discarded: C1
#
# Round 6 - NPC 2's turn
# NPC 2 drew: B5
# NPC 2 discarded: B2
#
# Round 6 - NPC 3's turn
# NPC 3 drew: C9
# NPC 3 discarded: C9
#
# Round 6 - NPC 4's turn
# NPC 4 drew: WS
# NPC 4 discarded: WW
#
# Round 7 - NPC 1's turn
# NPC 1 drew: B1
# NPC 1 discarded: C6
# NPC 2 吃 (Chi) [C4, C6, C5]
#
# Round 7 - NPC 2's turn
# NPC 2 discarded: B5
# NPC 3 吃 (Chi) [B4, B5, B6]
#
# Round 7 - NPC 3's turn
# NPC 3 discarded: C3
#
# Round 7 - NPC 4's turn
# NPC 4 drew: D3
# NPC 4 discarded: B7
# NPC 1 碰 (Peng) B7
#
# Round 8 - NPC 1's turn
# NPC 1 discarded: B6
#
# Round 8 - NPC 2's turn
# NPC 2 drew: C7
# NPC 2 discarded: C4
#
# Round 8 - NPC 3's turn
# NPC 3 drew: GR
# NPC 3 discarded: C5
#
# Round 8 - NPC 4's turn
# NPC 4 drew: B5
# NPC 4 discarded: B5
#
# Round 9 - NPC 1's turn
# NPC 1 drew: B6
# NPC 1 discarded: B6
#
# Round 9 - NPC 2's turn
# NPC 2 drew: WW
# NPC 2 discarded: WW
#
# Round 9 - NPC 3's turn
# NPC 3 drew: D7
# NPC 3 discarded: GR
#
# Round 9 - NPC 4's turn
# NPC 4 drew: B8
# NPC 4 discarded: D1
#
# Round 10 - NPC 1's turn
# NPC 1 drew: D2
# NPC 1 discarded: B9
# NPC 4 碰 (Peng) B9
#
# Round 10 - NPC 4's turn
# NPC 4 discarded: B8
#
# Round 11 - NPC 1's turn
# NPC 1 drew: D8
# NPC 1 discarded: D5
# 🎉 NPC 2 wins with a Hu hand by claiming the discarded tile D5! 🎉
# Game 986 result: NPC 2
#
# === Starting Game 987 ===
#
# Round 1 - NPC 3's turn
# NPC 3 drew: D4
# NPC 3 discarded: B1
#
# Round 1 - NPC 4's turn
# NPC 4 drew: B2
# NPC 4 discarded: C2
#
# Round 2 - NPC 1's turn
# NPC 1 drew: WN
# NPC 1 discarded: WN
#
# Round 2 - NPC 2's turn
# NPC 2 drew: C3
# NPC 2 discarded: B9
#
# Round 2 - NPC 3's turn
# NPC 3 drew: C2
# NPC 3 discarded: WW
#
# Round 2 - NPC 4's turn
# NPC 4 drew: C4
# NPC 4 discarded: C4
#
# Round 3 - NPC 1's turn
# NPC 1 drew: C8
# NPC 1 discarded: GR
#
# Round 3 - NPC 2's turn
# NPC 2 drew: C3
# NPC 2 discarded: GG
#
# Round 3 - NPC 3's turn
# NPC 3 drew: D6
# NPC 3 discarded: B9
#
# Round 3 - NPC 4's turn
# NPC 4 drew: B3
# NPC 4 discarded: C7
#
# Round 4 - NPC 1's turn
# NPC 1 drew: C1
# NPC 1 discarded: B1
# NPC 2 吃 (Chi) [B2, B1, B3]
#
# Round 4 - NPC 2's turn
# NPC 2 discarded: B1
#
# Round 4 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: C5
#
# Round 4 - NPC 4's turn
# NPC 4 drew: D7
# NPC 4 discarded: D7
#
# Round 5 - NPC 1's turn
# NPC 1 drew: B5
# NPC 1 discarded: D1
#
# Round 5 - NPC 2's turn
# NPC 2 drew: GR
# NPC 2 discarded: GR
#
# Round 5 - NPC 3's turn
# NPC 3 drew: D1
# NPC 3 discarded: D1
#
# Round 5 - NPC 4's turn
# NPC 4 drew: B8
# NPC 4 discarded: WS
# NPC 1 碰 (Peng) WS
#
# Round 6 - NPC 1's turn
# NPC 1 discarded: WS
#
# Round 6 - NPC 2's turn
# NPC 2 drew: C9
# NPC 2 discarded: C9
# NPC 3 吃 (Chi) [C7, C9, C8]
#
# Round 6 - NPC 3's turn
# NPC 3 discarded: D9
#
# Round 6 - NPC 4's turn
# NPC 4 drew: C8
# NPC 4 discarded: C8
# NPC 1 碰 (Peng) C8
#
# Round 7 - NPC 1's turn
# NPC 1 discarded: D7
#
# Round 7 - NPC 2's turn
# NPC 2 drew: D3
# NPC 2 discarded: C7
#
# Round 7 - NPC 3's turn
# NPC 3 drew: GH
# NPC 3 discarded: GH
# NPC 4 碰 (Peng) GH
#
# Round 7 - NPC 4's turn
# NPC 4 discarded: D1
#
# Round 8 - NPC 1's turn
# NPC 1 drew: C3
# NPC 1 discarded: C3
# NPC 2 碰 (Peng) C3
#
# Round 8 - NPC 2's turn
# NPC 2 discarded: B3
#
# Round 8 - NPC 3's turn
# NPC 3 drew: B7
# NPC 3 discarded: B6
# NPC 4 碰 (Peng) B6
#
# Round 8 - NPC 4's turn
# NPC 4 discarded: B5
# NPC 1 吃 (Chi) [B6, B5, B7]
#
# Round 9 - NPC 1's turn
# NPC 1 discarded: B5
#
# Round 9 - NPC 2's turn
# NPC 2 drew: WW
# NPC 2 discarded: B4
# 🎉 NPC 1 wins with a Hu hand by claiming the discarded tile B4! 🎉
# Game 987 result: NPC 1
#
# === Starting Game 988 ===
#
# Round 1 - NPC 4's turn
# NPC 4 drew: WN
# NPC 4 discarded: C3
#
# Round 2 - NPC 1's turn
# NPC 1 drew: C3
# NPC 1 discarded: WN
#
# Round 2 - NPC 2's turn
# NPC 2 drew: WE
# NPC 2 discarded: B1
#
# Round 2 - NPC 3's turn
# NPC 3 drew: WE
# NPC 3 discarded: B1
# NPC 4 吃 (Chi) [B2, B1, B3]
#
# Round 2 - NPC 4's turn
# NPC 4 discarded: B4
# NPC 1 吃 (Chi) [B5, B4, B6]
#
# Round 3 - NPC 1's turn
# NPC 1 discarded: WS
# NPC 4 碰 (Peng) WS
#
# Round 3 - NPC 4's turn
# NPC 4 discarded: C6
#
# Round 4 - NPC 1's turn
# NPC 1 drew: C2
# NPC 1 discarded: GG
#
# Round 4 - NPC 2's turn
# NPC 2 drew: C6
# NPC 2 discarded: B7
#
# Round 4 - NPC 3's turn
# NPC 3 drew: B7
# NPC 3 discarded: D6
#
# Round 4 - NPC 4's turn
# NPC 4 drew: WE
# NPC 4 discarded: C9
#
# Round 5 - NPC 1's turn
# NPC 1 drew: C7
# NPC 1 discarded: GR
#
# Round 5 - NPC 2's turn
# NPC 2 drew: B5
# NPC 2 discarded: B5
#
# Round 5 - NPC 3's turn
# NPC 3 drew: GH
# NPC 3 discarded: WE
# NPC 2 碰 (Peng) WE
#
# Round 5 - NPC 2's turn
# NPC 2 discarded: C2
# NPC 1 碰 (Peng) C2
#
# Round 5 - NPC 1's turn
# NPC 1 discarded: B8
#
# Round 5 - NPC 2's turn
# NPC 2 drew: B2
# NPC 2 discarded: B2
#
# Round 5 - NPC 3's turn
# NPC 3 drew: C8
# NPC 3 discarded: C8
#
# Round 5 - NPC 4's turn
# NPC 4 drew: B8
# NPC 4 discarded: B8
#
# Round 6 - NPC 1's turn
# NPC 1 drew: C6
# NPC 1 discarded: D4
#
# Round 6 - NPC 2's turn
# NPC 2 drew: B5
# NPC 2 discarded: B5
#
# Round 6 - NPC 3's turn
# NPC 3 drew: WW
# NPC 3 discarded: WN
#
# Round 6 - NPC 4's turn
# NPC 4 drew: GH
# NPC 4 discarded: D2
#
# Round 7 - NPC 1's turn
# NPC 1 drew: C1
# NPC 1 discarded: C1
#
# Round 7 - NPC 2's turn
# NPC 2 drew: B1
# NPC 2 discarded: B1
#
# Round 7 - NPC 3's turn
# NPC 3 drew: C9
# NPC 3 discarded: C9
#
# Round 7 - NPC 4's turn
# NPC 4 drew: GR
# NPC 4 discarded: WE
#
# Round 8 - NPC 1's turn
# NPC 1 drew: B1
# NPC 1 discarded: B1
#
# Round 8 - NPC 2's turn
# NPC 2 drew: B8
# NPC 2 discarded: B8
# NPC 3 吃 (Chi) [B7, B8, B9]
#
# Round 8 - NPC 3's turn
# NPC 3 discarded: WW
# NPC 4 碰 (Peng) WW
#
# Round 8 - NPC 4's turn
# NPC 4 discarded: WN
#
# Round 9 - NPC 1's turn
# NPC 1 drew: D1
# NPC 1 discarded: D1
#
# Round 9 - NPC 2's turn
# NPC 2 drew: GR
# NPC 2 discarded: GH
#
# Round 9 - NPC 3's turn
# NPC 3 drew: C4
# NPC 3 discarded: GG
#
# Round 9 - NPC 4's turn
# NPC 4 drew: B4
# NPC 4 discarded: B4
#
# Round 10 - NPC 1's turn
# NPC 1 drew: C8
# NPC 1 discarded: D7
#
# Round 10 - NPC 2's turn
# NPC 2 drew: D1
# NPC 2 discarded: GR
#
# Round 10 - NPC 3's turn
# NPC 3 drew: D4
# NPC 3 discarded: GH
#
# Round 10 - NPC 4's turn
# NPC 4 drew: D2
# NPC 4 discarded: D2
#
# Round 11 - NPC 1's turn
# NPC 1 drew: GG
# NPC 1 discarded: GG
#
# Round 11 - NPC 2's turn
# NPC 2 drew: D7
# NPC 2 discarded: C9
#
# Round 11 - NPC 3's turn
# NPC 3 drew: GG
# NPC 3 discarded: GG
#
# Round 11 - NPC 4's turn
# NPC 4 drew: B9
# NPC 4 discarded: B9
#
# Round 12 - NPC 1's turn
# NPC 1 drew: D9
# NPC 1 discarded: D8
#
# Round 12 - NPC 2's turn
# NPC 2 drew: B4
# NPC 2 discarded: B4
#
# Round 12 - NPC 3's turn
# NPC 3 drew: C8
# NPC 3 discarded: C8
#
# Round 12 - NPC 4's turn
# NPC 4 drew: C2
# NPC 4 discarded: C2
#
# Round 13 - NPC 1's turn
# NPC 1 drew: B4
# NPC 1 discarded: B4
#
# Round 13 - NPC 2's turn
# NPC 2 drew: B3
# NPC 2 discarded: B3
#
# Round 13 - NPC 3's turn
# NPC 3 drew: B9
# NPC 3 discarded: B9
#
# Round 13 - NPC 4's turn
# NPC 4 drew: D8
# NPC 4 discarded: GH
#
# Round 14 - NPC 1's turn
# NPC 1 drew: C6
# NPC 1 discarded: D9
# NPC 3 碰 (Peng) D9
#
# Round 14 - NPC 3's turn
# NPC 3 discarded: GR
#
# Round 14 - NPC 4's turn
# NPC 4 drew: B6
# NPC 4 discarded: B6
#
# Round 15 - NPC 1's turn
# NPC 1 drew: D6
# NPC 1 discarded: D6
# NPC 2 吃 (Chi) [D5, D6, D7]
#
# Round 15 - NPC 2's turn
# NPC 2 discarded: D7
#
# Round 15 - NPC 3's turn
# NPC 3 drew: D3
# NPC 3 discarded: C1
#
# Round 15 - NPC 4's turn
# NPC 4 drew: D4
# NPC 4 discarded: GR
#
# Round 16 - NPC 1's turn
# NPC 1 drew: D7
# NPC 1 discarded: D7
#
# Round 16 - NPC 2's turn
# NPC 2 drew: B8
# NPC 2 discarded: B8
#
# Round 16 - NPC 3's turn
# NPC 3 drew: C1
# NPC 3 discarded: C1
#
# Round 16 - NPC 4's turn
# NPC 4 drew: B6
# NPC 4 discarded: B6
#
# Round 17 - NPC 1's turn
# NPC 1 drew: B6
# NPC 1 discarded: B6
#
# Round 17 - NPC 2's turn
# NPC 2 drew: C7
# NPC 2 discarded: D2
# NPC 3 吃 (Chi) [D3, D2, D4]
#
# Round 17 - NPC 3's turn
# NPC 3 discarded: C3
# NPC 1 碰 (Peng) C3
#
# Round 17 - NPC 1's turn
# NPC 1 discarded: C8
# NPC 2 吃 (Chi) [C6, C8, C7]
#
# Round 17 - NPC 2's turn
# NPC 2 discarded: C7
# 🎉 NPC 1 wins with a Hu hand by claiming the discarded tile C7! 🎉
# Game 988 result: NPC 1
#
# === Starting Game 989 ===
#
# Round 1 - NPC 1's turn
# NPC 1 drew: GG
# NPC 1 discarded: WW
#
# Round 1 - NPC 2's turn
# NPC 2 drew: C5
# NPC 2 discarded: B9
#
# Round 1 - NPC 3's turn
# NPC 3 drew: B4
# NPC 3 discarded: C2
# NPC 4 吃 (Chi) [C1, C2, C3]
#
# Round 1 - NPC 4's turn
# NPC 4 discarded: C5
# NPC 1 吃 (Chi) [C6, C5, C7]
#
# Round 2 - NPC 1's turn
# NPC 1 discarded: D1
#
# Round 2 - NPC 2's turn
# NPC 2 drew: GR
# NPC 2 discarded: WN
# NPC 3 碰 (Peng) WN
#
# Round 2 - NPC 3's turn
# NPC 3 discarded: WE
#
# Round 2 - NPC 4's turn
# NPC 4 drew: B5
# NPC 4 discarded: C8
# NPC 2 碰 (Peng) C8
#
# Round 3 - NPC 2's turn
# NPC 2 discarded: C8
# NPC 3 吃 (Chi) [C6, C8, C7]
#
# Round 3 - NPC 3's turn
# NPC 3 discarded: B4
#
# Round 3 - NPC 4's turn
# NPC 4 drew: D4
# NPC 4 discarded: WN
#
# Round 4 - NPC 1's turn
# NPC 1 drew: C2
# NPC 1 discarded: D6
# NPC 3 碰 (Peng) D6
#
# Round 4 - NPC 3's turn
# NPC 3 discarded: B5
#
# Round 4 - NPC 4's turn
# NPC 4 drew: B7
# NPC 4 discarded: WW
#
# Round 5 - NPC 1's turn
# NPC 1 drew: C4
# NPC 1 discarded: D9
# NPC 2 吃 (Chi) [D7, D9, D8]
#
# Round 5 - NPC 2's turn
# NPC 2 discarded: D5
#
# Round 5 - NPC 3's turn
# NPC 3 drew: B2
# NPC 3 discarded: B2
#
# Round 5 - NPC 4's turn
# NPC 4 drew: C1
# NPC 4 discarded: C1
# NPC 1 吃 (Chi) [C2, C1, C3]
#
# Round 6 - NPC 1's turn
# NPC 1 discarded: B1
#
# Round 6 - NPC 2's turn
# NPC 2 drew: B8
# NPC 2 discarded: B8
#
# Round 6 - NPC 3's turn
# NPC 3 drew: WW
# NPC 3 discarded: WW
#
# Round 6 - NPC 4's turn
# NPC 4 drew: D5
# NPC 4 discarded: GH
# NPC 1 碰 (Peng) GH
#
# Round 7 - NPC 1's turn
# NPC 1 discarded: B2
# NPC 2 吃 (Chi) [B3, B2, B4]
#
# Round 7 - NPC 2's turn
# NPC 2 discarded: B5
#
# Round 7 - NPC 3's turn
# NPC 3 drew: B8
# NPC 3 discarded: B9
#
# Round 7 - NPC 4's turn
# NPC 4 drew: WW
# NPC 4 discarded: WW
#
# Round 8 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
#
# Round 8 - NPC 2's turn
# NPC 2 drew: C7
# 🎉 NPC 2 wins with a Hu hand! 🎉
# Game 989 result: NPC 2
#
# === Starting Game 990 ===
#
# Round 1 - NPC 2's turn
# NPC 2 drew: D8
# NPC 2 discarded: B6
# NPC 3 吃 (Chi) [B4, B6, B5]
#
# Round 1 - NPC 3's turn
# NPC 3 discarded: C1
#
# Round 1 - NPC 4's turn
# NPC 4 drew: WE
# NPC 4 discarded: B2
#
# Round 2 - NPC 1's turn
# NPC 1 drew: C4
# NPC 1 discarded: B3
#
# Round 2 - NPC 2's turn
# NPC 2 drew: WN
# NPC 2 discarded: WS
#
# Round 2 - NPC 3's turn
# NPC 3 drew: D4
# NPC 3 discarded: C8
#
# Round 2 - NPC 4's turn
# NPC 4 drew: B8
# NPC 4 discarded: C3
# NPC 1 吃 (Chi) [C4, C3, C5]
#
# Round 3 - NPC 1's turn
# NPC 1 discarded: C9
#
# Round 3 - NPC 2's turn
# NPC 2 drew: D6
# NPC 2 discarded: C9
#
# Round 3 - NPC 3's turn
# NPC 3 drew: D8
# NPC 3 discarded: D1
#
# Round 3 - NPC 4's turn
# NPC 4 drew: C5
# NPC 4 discarded: D6
# NPC 1 吃 (Chi) [D4, D6, D5]
#
# Round 4 - NPC 1's turn
# NPC 1 discarded: D2
# NPC 2 吃 (Chi) [D1, D2, D3]
#
# Round 4 - NPC 2's turn
# NPC 2 discarded: D6
# NPC 3 吃 (Chi) [D4, D6, D5]
#
# Round 4 - NPC 3's turn
# NPC 3 discarded: GR
#
# Round 4 - NPC 4's turn
# NPC 4 drew: C3
# NPC 4 discarded: WE
# NPC 3 碰 (Peng) WE
#
# Round 5 - NPC 3's turn
# NPC 3 discarded: B8
#
# Round 5 - NPC 4's turn
# NPC 4 drew: C6
# NPC 4 discarded: WS
#
# Round 6 - NPC 1's turn
# NPC 1 drew: B7
# NPC 1 discarded: B7
#
# Round 6 - NPC 2's turn
# NPC 2 drew: C9
# NPC 2 discarded: C9
#
# Round 6 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: D9
#
# Round 6 - NPC 4's turn
# NPC 4 drew: B8
# NPC 4 discarded: B6
#
# Round 7 - NPC 1's turn
# NPC 1 drew: WE
# NPC 1 discarded: WE
#
# Round 7 - NPC 2's turn
# NPC 2 drew: B6
# NPC 2 discarded: B6
#
# Round 7 - NPC 3's turn
# NPC 3 drew: C5
# NPC 3 discarded: C5
# NPC 4 吃 (Chi) [C6, C5, C7]
#
# Round 7 - NPC 4's turn
# NPC 4 discarded: C3
#
# Round 8 - NPC 1's turn
# NPC 1 drew: WW
# NPC 1 discarded: WW
#
# Round 8 - NPC 2's turn
# NPC 2 drew: D1
# NPC 2 discarded: D1
#
# Round 8 - NPC 3's turn
# NPC 3 drew: D7
# NPC 3 discarded: D7
#
# Round 8 - NPC 4's turn
# NPC 4 drew: D4
# NPC 4 discarded: C5
# NPC 1 吃 (Chi) [C6, C5, C7]
#
# Round 9 - NPC 1's turn
# NPC 1 discarded: D6
#
# Round 9 - NPC 2's turn
# NPC 2 drew: WS
# NPC 2 discarded: WS
#
# Round 9 - NPC 3's turn
# NPC 3 drew: B4
# NPC 3 discarded: B4
#
# Round 9 - NPC 4's turn
# NPC 4 drew: C1
# NPC 4 discarded: C1
#
# Round 10 - NPC 1's turn
# NPC 1 drew: B1
# NPC 1 discarded: B1
# NPC 2 吃 (Chi) [B2, B1, B3]
#
# Round 10 - NPC 2's turn
# NPC 2 discarded: C6
#
# Round 10 - NPC 3's turn
# NPC 3 drew: C3
# NPC 3 discarded: C3
#
# Round 10 - NPC 4's turn
# NPC 4 drew: B8
# NPC 4 discarded: B9
# 🎉 NPC 3 wins with a Hu hand by claiming the discarded tile B9! 🎉
# Game 990 result: NPC 3
#
# === Starting Game 991 ===
#
# Round 1 - NPC 3's turn
# NPC 3 drew: C2
# NPC 3 discarded: C8
#
# Round 1 - NPC 4's turn
# NPC 4 drew: D8
# NPC 4 discarded: C9
#
# Round 2 - NPC 1's turn
# NPC 1 drew: WN
# NPC 1 discarded: WN
#
# Round 2 - NPC 2's turn
# NPC 2 drew: C3
# NPC 2 discarded: B2
# NPC 3 吃 (Chi) [B1, B2, B3]
#
# Round 2 - NPC 3's turn
# NPC 3 discarded: B3
# NPC 4 吃 (Chi) [B4, B3, B5]
#
# Round 2 - NPC 4's turn
# NPC 4 discarded: WW
#
# Round 3 - NPC 1's turn
# NPC 1 drew: C9
# NPC 1 discarded: WS
#
# Round 3 - NPC 2's turn
# NPC 2 drew: B5
# NPC 2 discarded: B5
#
# Round 3 - NPC 3's turn
# NPC 3 drew: C5
# NPC 3 discarded: WE
#
# Round 3 - NPC 4's turn
# NPC 4 drew: GR
# NPC 4 discarded: GG
#
# Round 4 - NPC 1's turn
# NPC 1 drew: C1
# NPC 1 discarded: GG
#
# Round 4 - NPC 2's turn
# ...
# NPC 3 discarded: GG
#
# Round 9 - NPC 4's turn
# NPC 4 drew: B9
# NPC 4 discarded: B9
#
# Round 10 - NPC 1's turn
# NPC 1 drew: C2
# NPC 1 discarded: B2
#
# Round 10 - NPC 2's turn
# NPC 2 drew: C1
# NPC 2 discarded: C1
#
# Round 10 - NPC 3's turn
# NPC 3 drew: C6
# NPC 3 discarded: C6
#
# Round 10 - NPC 4's turn
# NPC 4 drew: C8
# NPC 4 discarded: C8
#
# Round 11 - NPC 1's turn
# NPC 1 drew: C7
# NPC 1 discarded: B3
#
# Round 11 - NPC 2's turn
# NPC 2 drew: C4
# NPC 2 discarded: C4
#
# Round 11 - NPC 3's turn
# NPC 3 drew: GH
# NPC 3 discarded: GH
# NPC 4 碰 (Peng) GH
#
# Round 11 - NPC 4's turn
# NPC 4 discarded: D8
# NPC 2 碰 (Peng) D8
#
# Round 12 - NPC 2's turn
# NPC 2 discarded: WE
#
# Round 12 - NPC 3's turn
# NPC 3 drew: C8
# NPC 3 discarded: C8
#
# Round 12 - NPC 4's turn
# NPC 4 drew: C6
# NPC 4 discarded: C6
# NPC 1 吃 (Chi) [C4, C6, C5]
#
# Round 13 - NPC 1's turn
# NPC 1 discarded: B4
#
# Round 13 - NPC 2's turn
# NPC 2 drew: D1
# NPC 2 discarded: D1
#
# Round 13 - NPC 3's turn
# NPC 3 drew: D3
# NPC 3 discarded: D3
#
# Round 13 - NPC 4's turn
# NPC 4 drew: C7
# NPC 4 discarded: C7
#
# Round 14 - NPC 1's turn
# NPC 1 drew: WW
# NPC 1 discarded: WW
#
# Round 14 - NPC 2's turn
# NPC 2 drew: GH
# NPC 2 discarded: GG
#
# Round 14 - NPC 3's turn
# NPC 3 drew: D2
# NPC 3 discarded: D2
#
# Round 14 - NPC 4's turn
# NPC 4 drew: C5
# NPC 4 discarded: C5
# NPC 1 吃 (Chi) [C6, C5, C7]
#
# Round 15 - NPC 1's turn
# NPC 1 discarded: C2
#
# Round 15 - NPC 2's turn
# NPC 2 drew: B6
# NPC 2 discarded: GH
#
# Round 15 - NPC 3's turn
# NPC 3 drew: D8
# NPC 3 discarded: D8
#
# Round 15 - NPC 4's turn
# NPC 4 drew: GG
# NPC 4 discarded: GG
#
# Round 16 - NPC 1's turn
# NPC 1 drew: C8
# NPC 1 discarded: C3
#
# Round 16 - NPC 2's turn
# NPC 2 drew: B8
# NPC 2 discarded: B9
#
# Round 16 - NPC 3's turn
# NPC 3 drew: D2
# NPC 3 discarded: D2
#
# Round 16 - NPC 4's turn
# NPC 4 drew: C5
# NPC 4 discarded: C5
#
# Round 17 - NPC 1's turn
# NPC 1 drew: D4
# NPC 1 discarded: C8
#
# Round 17 - NPC 2's turn
# NPC 2 drew: C6
# NPC 2 discarded: C6
#
# Round 17 - NPC 3's turn
# NPC 3 drew: WE
# NPC 3 discarded: WE
#
# Round 17 - NPC 4's turn
# NPC 4 drew: B9
# NPC 4 discarded: B9
#
# Round 18 - NPC 1's turn
# NPC 1 drew: WW
# NPC 1 discarded: WW
#
# Round 18 - NPC 2's turn
# NPC 2 drew: C1
# NPC 2 discarded: C1
#
# Round 18 - NPC 3's turn
# NPC 3 drew: WN
# NPC 3 discarded: WN
#
# Round 18 - NPC 4's turn
# NPC 4 drew: WE
# NPC 4 discarded: WE
#
# Round 19 - NPC 1's turn
# NPC 1 drew: C9
# NPC 1 discarded: C9
#
# Round 19 - NPC 2's turn
# NPC 2 drew: B5
# NPC 2 discarded: B5
# 🎉 NPC 3 wins with a Hu hand by claiming the discarded tile B5! 🎉
# Game 995 result: NPC 3
#
# === Starting Game 996 ===
#
# Round 1 - NPC 4's turn
# NPC 4 drew: B8
# NPC 4 discarded: C2
# NPC 1 吃 (Chi) [C3, C2, C4]
#
# Round 2 - NPC 1's turn
# NPC 1 discarded: WE
#
# Round 2 - NPC 2's turn
# NPC 2 drew: WN
# NPC 2 discarded: B1
#
# Round 2 - NPC 3's turn
# NPC 3 drew: C3
# NPC 3 discarded: C3
#
# Round 2 - NPC 4's turn
# NPC 4 drew: C8
# NPC 4 discarded: WN
#
# Round 3 - NPC 1's turn
# NPC 1 drew: C3
# NPC 1 discarded: WN
#
# Round 3 - NPC 2's turn
# NPC 2 drew: C4
# NPC 2 discarded: B4
# NPC 3 吃 (Chi) [B3, B4, B5]
#
# Round 3 - NPC 3's turn
# NPC 3 discarded: B3
#
# Round 3 - NPC 4's turn
# NPC 4 drew: B1
# NPC 4 discarded: B1
#
# Round 4 - NPC 1's turn
# NPC 1 drew: C9
# NPC 1 discarded: WW
#
# Round 4 - NPC 2's turn
# NPC 2 drew: C1
# NPC 2 discarded: C1
#
# Round 4 - NPC 3's turn
# NPC 3 drew: B4
# NPC 3 discarded: D2
# NPC 2 碰 (Peng) D2
#
# Round 4 - NPC 2's turn
# NPC 2 discarded: WN
#
# Round 4 - NPC 3's turn
# NPC 3 drew: GR
# NPC 3 discarded: WW
#
# Round 4 - NPC 4's turn
# NPC 4 drew: B6
# NPC 4 discarded: WW
#
# Round 5 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
#
# Round 5 - NPC 2's turn
# NPC 2 drew: GG
# NPC 2 discarded: WS
#
# Round 5 - NPC 3's turn
# NPC 3 drew: B8
# NPC 3 discarded: GG
#
# Round 5 - NPC 4's turn
# NPC 4 drew: B7
# NPC 4 discarded: GR
#
# Round 6 - NPC 1's turn
# NPC 1 drew: C5
# NPC 1 discarded: GG
#
# Round 6 - NPC 2's turn
# NPC 2 drew: B2
# NPC 2 discarded: B2
#
# Round 6 - NPC 3's turn
# NPC 3 drew: B5
# NPC 3 discarded: GH
#
# Round 6 - NPC 4's turn
# NPC 4 drew: B9
# NPC 4 discarded: B6
# NPC 3 碰 (Peng) B6
#
# Round 7 - NPC 3's turn
# NPC 3 discarded: B8
#
# Round 7 - NPC 4's turn
# NPC 4 drew: D4
# NPC 4 discarded: B7
#
# Round 8 - NPC 1's turn
# NPC 1 drew: WN
# NPC 1 discarded: WN
#
# Round 8 - NPC 2's turn
# NPC 2 drew: GH
# NPC 2 discarded: GG
#
# Round 8 - NPC 3's turn
# NPC 3 drew: B7
# NPC 3 discarded: GR
#
# Round 8 - NPC 4's turn
# NPC 4 drew: B8
# NPC 4 discarded: D3
#
# Round 9 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
#
# Round 9 - NPC 2's turn
# NPC 2 drew: WE
# NPC 2 discarded: WE
#
# Round 9 - NPC 3's turn
# NPC 3 drew: C9
# NPC 3 discarded: B7
# NPC 4 吃 (Chi) [B8, B7, B9]
#
# Round 9 - NPC 4's turn
# NPC 4 discarded: B8
# NPC 1 吃 (Chi) [B7, B8, B9]
#
# Round 10 - NPC 1's turn
# NPC 1 discarded: B3
#
# Round 10 - NPC 2's turn
# NPC 2 drew: C1
# NPC 2 discarded: C1
#
# Round 10 - NPC 3's turn
# NPC 3 drew: C7
# NPC 3 discarded: B4
#
# Round 10 - NPC 4's turn
# NPC 4 drew: D7
# NPC 4 discarded: B9
#
# Round 11 - NPC 1's turn
# NPC 1 drew: B5
# NPC 1 discarded: B5
#
# Round 11 - NPC 2's turn
# NPC 2 drew: C1
# NPC 2 discarded: C1
#
# Round 11 - NPC 3's turn
# NPC 3 drew: C6
# NPC 3 discarded: B5
#
# Round 11 - NPC 4's turn
# NPC 4 drew: C7
# 🎉 NPC 4 wins with a Hu hand! 🎉
# Game 996 result: NPC 4
#
# === Starting Game 997 ===
#
# Round 1 - NPC 1's turn
# NPC 1 drew: WW
# NPC 1 discarded: GH
#
# Round 1 - NPC 2's turn
# NPC 2 drew: D2
# NPC 2 discarded: B4
#
# Round 1 - NPC 3's turn
# NPC 3 drew: C2
# NPC 3 discarded: B3
#
# Round 1 - NPC 4's turn
# NPC 4 drew: C9
# NPC 4 discarded: B5
#
# Round 2 - NPC 1's turn
# NPC 1 drew: GR
# NPC 1 discarded: GR
#
# Round 2 - NPC 2's turn
# NPC 2 drew: WW
# NPC 2 discarded: D2
# NPC 3 碰 (Peng) D2
#
# Round 2 - NPC 3's turn
# NPC 3 discarded: WN
#
# Round 2 - NPC 4's turn
# NPC 4 drew: C7
# NPC 4 discarded: B8
#
# Round 3 - NPC 1's turn
# NPC 1 drew: D1
# NPC 1 discarded: B4
#
# Round 3 - NPC 2's turn
# NPC 2 drew: B5
# NPC 2 discarded: B5
#
# Round 3 - NPC 3's turn
# NPC 3 drew: C7
# NPC 3 discarded: C7
#
# Round 3 - NPC 4's turn
# NPC 4 drew: C1
# NPC 4 discarded: D1
#
# Round 4 - NPC 1's turn
# NPC 1 drew: B2
# NPC 1 discarded: B2
# NPC 4 碰 (Peng) B2
#
# Round 4 - NPC 4's turn
# NPC 4 discarded: D9
#
# Round 5 - NPC 1's turn
# NPC 1 drew: WN
# NPC 1 discarded: WN
#
# Round 5 - NPC 2's turn
# NPC 2 drew: B8
# NPC 2 discarded: D5
# NPC 3 吃 (Chi) [D4, D5, D6]
#
# Round 5 - NPC 3's turn
# NPC 3 discarded: D3
#
# Round 5 - NPC 4's turn
# NPC 4 drew: D5
# NPC 4 discarded: D5
# NPC 1 吃 (Chi) [D3, D5, D4]
#
# Round 6 - NPC 1's turn
# NPC 1 discarded: B7
# NPC 2 吃 (Chi) [B8, B7, B9]
#
# Round 6 - NPC 2's turn
# NPC 2 discarded: B8
#
# Round 6 - NPC 3's turn
# NPC 3 drew: D4
# NPC 3 discarded: WS
#
# Round 6 - NPC 4's turn
# NPC 4 drew: D6
# NPC 4 discarded: D6
#
# Round 7 - NPC 1's turn
# NPC 1 drew: C1
# NPC 1 discarded: C1
# NPC 2 吃 (Chi) [C2, C1, C3]
#
# Round 7 - NPC 2's turn
# NPC 2 discarded: D9
#
# Round 7 - NPC 3's turn
# NPC 3 drew: C4
# NPC 3 discarded: C4
# NPC 4 吃 (Chi) [C2, C4, C3]
#
# Round 7 - NPC 4's turn
# NPC 4 discarded: C1
#
# Round 8 - NPC 1's turn
# NPC 1 drew: B7
# NPC 1 discarded: B7
#
# Round 8 - NPC 2's turn
# NPC 2 drew: C5
# NPC 2 discarded: WE
# NPC 1 碰 (Peng) WE
#
# Round 8 - NPC 1's turn
# NPC 1 discarded: D1
#
# Round 8 - NPC 2's turn
# NPC 2 drew: B3
# NPC 2 discarded: B3
#
# Round 8 - NPC 3's turn
# NPC 3 drew: WE
# NPC 3 discarded: WE
#
# Round 8 - NPC 4's turn
# NPC 4 drew: D7
# NPC 4 discarded: D7
#
# Round 9 - NPC 1's turn
# NPC 1 drew: B6
# NPC 1 discarded: B6
#
# Round 9 - NPC 2's turn
# NPC 2 drew: B3
# NPC 2 discarded: B3
#
# Round 9 - NPC 3's turn
# NPC 3 drew: C7
# NPC 3 discarded: C7
#
# Round 9 - NPC 4's turn
# NPC 4 drew: D3
# NPC 4 discarded: D3
#
# Round 10 - NPC 1's turn
# NPC 1 drew: D6
# NPC 1 discarded: D6
#
# Round 10 - NPC 2's turn
# NPC 2 drew: D3
# NPC 2 discarded: D3
#
# Round 10 - NPC 3's turn
# NPC 3 drew: B3
# NPC 3 discarded: B3
#
# Round 10 - NPC 4's turn
# NPC 4 drew: C8
# NPC 4 discarded: WN
#
# Round 11 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
#
# Round 11 - NPC 2's turn
# NPC 2 drew: C8
# NPC 2 discarded: GH
#
# Round 11 - NPC 3's turn
# NPC 3 drew: B4
# NPC 3 discarded: B4
#
# Round 11 - NPC 4's turn
# NPC 4 drew: B7
# NPC 4 discarded: B7
#
# Round 12 - NPC 1's turn
# NPC 1 drew: GR
# NPC 1 discarded: GR
#
# Round 12 - NPC 2's turn
# NPC 2 drew: D4
# NPC 2 discarded: D4
#
# Round 12 - NPC 3's turn
# NPC 3 drew: D5
# NPC 3 discarded: C1
#
# Round 12 - NPC 4's turn
# NPC 4 drew: B6
# NPC 4 discarded: B6
#
# Round 13 - NPC 1's turn
# NPC 1 drew: C4
# NPC 1 discarded: C4
# NPC 2 吃 (Chi) [C5, C4, C6]
#
# Round 13 - NPC 2's turn
# NPC 2 discarded: C9
#
# Round 13 - NPC 3's turn
# NPC 3 drew: C9
# NPC 3 discarded: C2
#
# Round 13 - NPC 4's turn
# NPC 4 drew: D7
# NPC 4 discarded: D7
#
# Round 14 - NPC 1's turn
# NPC 1 drew: C5
# NPC 1 discarded: D8
# NPC 3 碰 (Peng) D8
#
# Round 14 - NPC 3's turn
# NPC 3 discarded: C9
# NPC 4 吃 (Chi) [C7, C9, C8]
#
# Round 14 - NPC 4's turn
# NPC 4 discarded: C9
#
# Round 15 - NPC 1's turn
# NPC 1 drew: D7
# NPC 1 discarded: D7
#
# Round 15 - NPC 2's turn
# NPC 2 drew: D9
# NPC 2 discarded: D9
# 🎉 NPC 3 wins with a Hu hand by claiming the discarded tile D9! 🎉
# Game 997 result: NPC 3
#
# === Starting Game 998 ===
#
# Round 1 - NPC 2's turn
# NPC 2 drew: B3
# NPC 2 discarded: B9
#
# Round 1 - NPC 3's turn
# NPC 3 drew: C1
# NPC 3 discarded: D8
# NPC 4 吃 (Chi) [D7, D8, D9]
#
# Round 1 - NPC 4's turn
# NPC 4 discarded: B8
#
# Round 2 - NPC 1's turn
# NPC 1 drew: C8
# NPC 1 discarded: GG
#
# Round 2 - NPC 2's turn
# NPC 2 drew: C3
# NPC 2 discarded: C3
# NPC 4 碰 (Peng) C3
#
# Round 2 - NPC 4's turn
# NPC 4 discarded: C8
# NPC 1 碰 (Peng) C8
#
# Round 3 - NPC 1's turn
# NPC 1 discarded: D1
#
# Round 3 - NPC 2's turn
# NPC 2 drew: C6
# NPC 2 discarded: D3
#
# Round 3 - NPC 3's turn
# NPC 3 drew: D3
# NPC 3 discarded: D3
#
# Round 3 - NPC 4's turn
# NPC 4 drew: C7
# NPC 4 discarded: C7
#
# Round 4 - NPC 1's turn
# NPC 1 drew: GG
# NPC 1 discarded: GG
#
# Round 4 - NPC 2's turn
# NPC 2 drew: D4
# NPC 2 discarded: WE
#
# Round 4 - NPC 3's turn
# NPC 3 drew: D9
# NPC 3 discarded: D9
#
# Round 4 - NPC 4's turn
# NPC 4 drew: B4
# NPC 4 discarded: D2
#
# Round 5 - NPC 1's turn
# NPC 1 drew: B4
# NPC 1 discarded: B4
#
# Round 5 - NPC 2's turn
# NPC 2 drew: WN
# NPC 2 discarded: WW
#
# Round 5 - NPC 3's turn
# NPC 3 drew: D5
# NPC 3 discarded: D5
#
# Round 5 - NPC 4's turn
# NPC 4 drew: C6
# NPC 4 discarded: C6
# NPC 1 吃 (Chi) [C4, C6, C5]
#
# Round 6 - NPC 1's turn
# NPC 1 discarded: D4
#
# Round 6 - NPC 2's turn
# NPC 2 drew: B7
# NPC 2 discarded: C9
# NPC 3 碰 (Peng) C9
#
# Round 6 - NPC 3's turn
# NPC 3 discarded: WS
#
# Round 6 - NPC 4's turn
# NPC 4 drew: GR
# NPC 4 discarded: D9
# NPC 1 吃 (Chi) [D7, D9, D8]
#
# Round 7 - NPC 1's turn
# NPC 1 discarded: B1
#
# Round 7 - NPC 2's turn
# NPC 2 drew: C9
# NPC 2 discarded: C9
#
# Round 7 - NPC 3's turn
# NPC 3 drew: WE
# NPC 3 discarded: WE
#
# Round 7 - NPC 4's turn
# NPC 4 drew: B4
# NPC 4 discarded: WE
#
# Round 8 - NPC 1's turn
# NPC 1 drew: C5
# NPC 1 discarded: C5
# NPC 2 吃 (Chi) [C6, C5, C7]
#
# Round 8 - NPC 2's turn
# NPC 2 discarded: D4
#
# Round 8 - NPC 3's turn
# NPC 3 drew: GR
# NPC 3 discarded: B1
# NPC 4 吃 (Chi) [B2, B1, B3]
#
# Round 8 - NPC 4's turn
# NPC 4 discarded: B1
#
# Round 9 - NPC 1's turn
# NPC 1 drew: WE
# NPC 1 discarded: WE
#
# Round 9 - NPC 2's turn
# NPC 2 drew: D5
# NPC 2 discarded: B7
#
# Round 9 - NPC 3's turn
# NPC 3 drew: C1
# NPC 3 discarded: B2
# 🎉 NPC 1 wins with a Hu hand by claiming the discarded tile B2! 🎉
# Game 998 result: NPC 1
#
# === Starting Game 999 ===
#
# Round 1 - NPC 3's turn
# NPC 3 drew: C2
# NPC 3 discarded: D1
#
# Round 1 - NPC 4's turn
# NPC 4 drew: WW
# NPC 4 discarded: B1
#
# Round 2 - NPC 1's turn
# NPC 1 drew: WE
# NPC 1 discarded: WE
#
# Round 2 - NPC 2's turn
# NPC 2 drew: C4
# NPC 2 discarded: C1
# NPC 3 吃 (Chi) [C2, C1, C3]
#
# Round 2 - NPC 3's turn
# NPC 3 discarded: D6
#
# Round 2 - NPC 4's turn
# NPC 4 drew: D6
# NPC 4 discarded: B5
#
# Round 3 - NPC 1's turn
# NPC 1 drew: D8
# NPC 1 discarded: WN
#
# Round 3 - NPC 2's turn
# NPC 2 drew: C5
# NPC 2 discarded: GR
#
# Round 3 - NPC 3's turn
# NPC 3 drew: C6
# NPC 3 discarded: D9
#
# Round 3 - NPC 4's turn
# NPC 4 drew: C7
# NPC 4 discarded: C2
#
# Round 4 - NPC 1's turn
# NPC 1 drew: B6
# NPC 1 discarded: WS
#
# Round 4 - NPC 2's turn
# NPC 2 drew: C1
# NPC 2 discarded: C1
#
# Round 4 - NPC 3's turn
# NPC 3 drew: B8
# NPC 3 discarded: B8
#
# Round 4 - NPC 4's turn
# NPC 4 drew: B1
# NPC 4 discarded: B1
#
# Round 5 - NPC 1's turn
# NPC 1 drew: C3
# NPC 1 discarded: C8
#
# Round 5 - NPC 2's turn
# NPC 2 drew: B8
# NPC 2 discarded: B8
#
# Round 5 - NPC 3's turn
# NPC 3 drew: D1
# NPC 3 discarded: D1
#
# Round 5 - NPC 4's turn
# NPC 4 drew: B5
# NPC 4 discarded: B5
#
# Round 6 - NPC 1's turn
# NPC 1 drew: WN
# NPC 1 discarded: WN
#
# Round 6 - NPC 2's turn
# NPC 2 drew: C3
# NPC 2 discarded: D5
#
# Round 6 - NPC 3's turn
# NPC 3 drew: B1
# NPC 3 discarded: B1
#
# Round 6 - NPC 4's turn
# NPC 4 drew: B2
# NPC 4 discarded: B2
#
# Round 7 - NPC 1's turn
# NPC 1 drew: B7
# NPC 1 discarded: D2
# NPC 2 碰 (Peng) D2
#
# Round 7 - NPC 2's turn
# NPC 2 discarded: D3
#
# Round 7 - NPC 3's turn
# NPC 3 drew: GR
# NPC 3 discarded: GR
#
# Round 7 - NPC 4's turn
# NPC 4 drew: GR
# NPC 4 discarded: D2
#
# Round 8 - NPC 1's turn
# NPC 1 drew: D9
# NPC 1 discarded: D4
#
# Round 8 - NPC 2's turn
# NPC 2 drew: B4
# NPC 2 discarded: B4
# NPC 3 碰 (Peng) B4
#
# Round 8 - NPC 3's turn
# NPC 3 discarded: C1
#
# Round 8 - NPC 4's turn
# NPC 4 drew: B2
# NPC 4 discarded: B2
#
# Round 9 - NPC 1's turn
# NPC 1 drew: WS
# NPC 1 discarded: WS
#
# Round 9 - NPC 2's turn
# NPC 2 drew: D7
# NPC 2 discarded: D8
# NPC 1 碰 (Peng) D8
#
# Round 9 - NPC 1's turn
# NPC 1 discarded: D7
# NPC 2 碰 (Peng) D7
#
# Round 9 - NPC 2's turn
# NPC 2 discarded: C3
#
# Round 9 - NPC 3's turn
# NPC 3 drew: B5
# NPC 3 discarded: B5
#
# Round 9 - NPC 4's turn
# NPC 4 drew: B2
# NPC 4 discarded: B2
#
# Round 10 - NPC 1's turn
# NPC 1 drew: B2
# NPC 1 discarded: B2
#
# Round 10 - NPC 2's turn
# NPC 2 drew: B5
# NPC 2 discarded: B5
#
# Round 10 - NPC 3's turn
# NPC 3 drew: GH
# NPC 3 discarded: C2
#
# Round 10 - NPC 4's turn
# NPC 4 drew: D5
# NPC 4 discarded: WE
#
# Round 11 - NPC 1's turn
# NPC 1 drew: B3
# NPC 1 discarded: C3
# NPC 2 吃 (Chi) [C4, C3, C5]
#
# Round 11 - NPC 2's turn
# NPC 2 discarded: C4
# NPC 3 吃 (Chi) [C5, C4, C6]
#
# Round 11 - NPC 3's turn
# NPC 3 discarded: C6
# NPC 4 吃 (Chi) [C7, C6, C8]
#
# Round 11 - NPC 4's turn
# NPC 4 discarded: C6
#
# Round 12 - NPC 1's turn
# NPC 1 drew: B4
# NPC 1 discarded: C4
#
# Round 12 - NPC 2's turn
# NPC 2 drew: C7
# 🎉 NPC 2 wins with a Hu hand! 🎉
# Game 999 result: NPC 2
#
# === Starting Game 1000 ===
#
# Round 1 - NPC 4's turn
# NPC 4 drew: C6
# NPC 4 discarded: C6
#
# Round 2 - NPC 1's turn
# NPC 1 drew: WE
# NPC 1 discarded: WE
#
# Round 2 - NPC 2's turn
# NPC 2 drew: C5
# NPC 2 槓 (Gong) declared with D3
# NPC 2 draws supplemental tile: B3
# NPC 2 discarded: B8
#
# Round 2 - NPC 3's turn
# NPC 3 drew: B2
# NPC 3 discarded: B2
# NPC 2 碰 (Peng) B2
#
# Round 2 - NPC 2's turn
# NPC 2 discarded: C5
#
# Round 2 - NPC 3's turn
# NPC 3 drew: D2
# NPC 3 discarded: B6
#
# Round 2 - NPC 4's turn
# NPC 4 drew: GH
# NPC 4 discarded: D1
#
# Round 3 - NPC 1's turn
# NPC 1 drew: B8
# NPC 1 discarded: GR
#
# Round 3 - NPC 2's turn
# NPC 2 drew: D6
# NPC 2 discarded: C7
#
# Round 3 - NPC 3's turn
# NPC 3 drew: WW
# NPC 3 discarded: C2
# NPC 4 碰 (Peng) C2
#
# Round 3 - NPC 4's turn
# NPC 4 discarded: C3
#
# Round 4 - NPC 1's turn
# NPC 1 drew: C3
# NPC 1 discarded: C1
#
# Round 4 - NPC 2's turn
# NPC 2 drew: C7
# NPC 2 discarded: C7
#
# Round 4 - NPC 3's turn
# NPC 3 drew: B4
# NPC 3 discarded: B4
# NPC 1 碰 (Peng) B4
#
# Round 4 - NPC 1's turn
# NPC 1 discarded: B7
#
# Round 4 - NPC 2's turn
# NPC 2 drew: D8
# NPC 2 discarded: D6
#
# Round 4 - NPC 3's turn
# NPC 3 drew: D6
# NPC 3 discarded: WS
#
# Round 4 - NPC 4's turn
# NPC 4 drew: D2
# NPC 4 discarded: WW
#
# Round 5 - NPC 1's turn
# NPC 1 drew: D5
# NPC 1 discarded: B8
#
# Round 5 - NPC 2's turn
# NPC 2 drew: D7
# NPC 2 discarded: D7
#
# Round 5 - NPC 3's turn
# NPC 3 drew: D1
# NPC 3 discarded: WW
#
# Round 5 - NPC 4's turn
# NPC 4 drew: GH
# NPC 4 discarded: B8
#
# Round 6 - NPC 1's turn
# NPC 1 drew: WN
# NPC 1 discarded: D5
#
# Round 6 - NPC 2's turn
# NPC 2 drew: C8
# NPC 2 discarded: C8
#
# Round 6 - NPC 3's turn
# NPC 3 drew: GG
# NPC 3 discarded: GG
#
# Round 6 - NPC 4's turn
# NPC 4 drew: C1
# NPC 4 discarded: C1
#
# Round 7 - NPC 1's turn
# NPC 1 drew: WE
# NPC 1 discarded: WE
#
# Round 7 - NPC 2's turn
# NPC 2 drew: B9
# NPC 2 discarded: B9
# NPC 3 碰 (Peng) B9
#
# Round 7 - NPC 3's turn
# NPC 3 discarded: C5
#
# Round 7 - NPC 4's turn
# NPC 4 drew: D5
# NPC 4 discarded: D2
#
# Round 8 - NPC 1's turn
# NPC 1 drew: B9
# NPC 1 discarded: B9
#
# Round 8 - NPC 2's turn
# NPC 2 drew: GR
# NPC 2 discarded: D8
# NPC 1 碰 (Peng) D8
#
# Round 8 - NPC 1's turn
# NPC 1 discarded: C3
#
# Round 8 - NPC 2's turn
# NPC 2 drew: D5
# NPC 2 discarded: D5
# NPC 3 吃 (Chi) [D4, D5, D6]
#
# Round 8 - NPC 3's turn
# NPC 3 discarded: D4
# NPC 4 吃 (Chi) [D5, D4, D6]
#
# Round 8 - NPC 4's turn
# NPC 4 discarded: D4
#
# Round 9 - NPC 1's turn
# NPC 1 drew: C4
# 🎉 NPC 1 wins with a Hu hand! 🎉
# Game 1000 result: NPC 1
#
# === Simulation Results ===
# NPC 1: 244 win(s)
# NPC 2: 265 win(s)
# NPC 3: 247 win(s)
# NPC 4: 244 win(s)
# Draw: 0 win(s)
